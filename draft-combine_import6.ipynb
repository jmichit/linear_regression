# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import os.path
import pickle
from IPython.core.debugger import set_trace

# %% [markdown]
# ## Scraping the Draft list

# %%
def readstat(row, tag, stat):
    """
    finds *tag* in table *row* with attribute: "data-stat" == *stat*
    """
    temp = row.find(tag, attrs = {"data-stat" : stat})
    if temp is None:
        return None
    else:
        return temp.text

# %%
def create_draft_df(bs_obj):
    """
    Returns draft info dataframe from profootballreference using
    BeautifulSoup object
    """
    
    table = bs.find("table", class_ = 'sortable stats_table').find_all('tr')    

    #columns of interest
    data_columns = ['draft_pick', 'team', 'player', 'pos', 'age', 'year_max', 'g', 'college_id']

    drafted = []    

    for row in table[2:-1]:
        rowdata = {}

        # Get data column in <TH>
        rowdata['draft_round'] = readstat(row, "th", "draft_round")

        # Get data columns in <TD>
        for col in data_columns:
            rowdata[col] = readstat(row, "td", col)

        # Get player link
        x = row.find("td", attrs = {'data-stat' : 'player'})

        if x is None:
            continue

        if x.find("a") is None:
            rowdata['player_link'] = ""
        else:
            rowdata['player_link'] = x.find("a").get('href')

        # Get college link
        x = row.find("td", attrs = {'data-stat' : 'college_link'})

        if x is None:
            continue

        if x.find("a") is None:
            rowdata['college_link'] = ""
        else:
            rowdata['college_link'] = x.find("a").get('href')            
            
        drafted.append(rowdata)    

    return pd.DataFrame(drafted)

# %% [markdown]
# ## Scraping the Combine

# %%
def create_combine_df(bs_obj):
    """
    Returns Combine info dataframe from profootballreference using
    BeautifulSoup object
    """
    #set_trace()
    year = bs_obj.h1.text[:4]
    
    ctable = bs_obj.find("table")
    
    #columns of interest
    data_columns = "pos school_name height weight forty_yd vertical bench_reps broad_jump cone shuttle".split()

    combine = []    

    for row in ctable.find_all('tr')[1:]:
        rowdata = {}

        try:
            #rowdata['player'] = row.find("th", attrs = {"csk":True}).text
            th = row.find("th", attrs = {"data-stat":'player'})
            if th:
                if th.a:
                    rowdata['player'] = th.a.text
                    rowdata['player_link'] = th.a.get('href')
                else:
                    rowdata['player'] = th.text
                    rowdata['player_link'] = ''
            else:
                continue
        except AttributeError:
            set_trace()
            continue

        # Get data columns
        for col in data_columns:
            rowdata[col] = readstat(row, "td", col)

        rowdata['year'] = year    
        
        combine.append(rowdata)    
    
    return pd.DataFrame(combine)

# %%
def convertHeighttoIn(x):
    """
    Converts player height in feet-inches to inches
    """
    try:
        feet, inches = x.split("-")
        return int(feet) * 12 + int(inches)
    except:
        return 0

# %%
def calcBMI(h, w):
    """
    Calculates BMI based on height (inches) and weight (lbs)
    """
    if (h == 0) or (w == 0):
        return 0
    else:
        return w / h**2 * 703

# %%
def create_combine_df_altsite(bs_obj):
    """
    Pulls combine data from alternative site for pre-2000 data
    """ 
    columns = ["year", "player", "school_name", "pos", "height", "weight", "wonderlic", 
              "forty_yd", "bench_reps", "vertical", "broad_jump", "shuttle", "cone"]

    #set_trace()
    tbl = bs_obj.find("table")
    combine = []
    for row in tbl.find_all("tr"):
        #set_trace()
        rowdata = {}
        for i, td in enumerate(row.find_all("td")):
            #set_trace()
            if td.div:
                rowdata[columns[i]] = td.text
            elif td.a:
                #set_trace()
                rowdata[columns[i]] = td.a.text
            else:
                rowdata[columns[i]] = td.text
        #print("row:", rowdata)
        combine.append(rowdata) 
    
    return pd.DataFrame(combine)

# %%
#first available combine

years = range(1990, 2011, 1)

draft_url = "https://www.pro-football-reference.com/years/{}/draft.htm"
combine_url = "https://www.pro-football-reference.com/draft/{}-combine.htm"
combine_url_alt = "https://nflcombineresults.com/nflcombinedata.php?year={}&pos=&college="

dflist = []

for year in years:
    #get draft for *year*
    
    url_d = draft_url.format(year)
    url_c = combine_url.format(year)
    url_c_alt = combine_url_alt.format(year)
    download_d = "data/{}_draft.pkl".format(year)
    download_c = "data/{}_combine.pkl".format(year)
    download_c_alt = "data/{}_combine_alt.pkl".format(year)
    text = ""
    
    print(f"Year: {year}")
    
    if os.path.exists(download_d):
        #if html file has already been downloaded, use it
        print(f"Draft year {year} already downloaded; loading from file")
        with open(download_d, "rb") as file:
            response = pickle.load(file)
    else:
        #otherwise pull the data from the url
        print(f"Draft year {year} downloaded and saved to file")        
        response = requests.get(url_d)
        with open(download_d, "wb") as file:
            pickle.dump(response, file)                        
         
    bs = BeautifulSoup(response.text, "html5lib" )
   # print("bs >>>>>>>>>>>>>>>>>>>>>" , bs)
    df1 = create_draft_df(bs)
    #print("Draft:", df1.head())
    
    if year >= 2000:
        #use primary site
        if os.path.exists(download_c):
            #if html file has already been downloaded, use it
            print(f"Combine year {year} already downloaded; loading from file")
            with open(download_c, "rb") as file:
                response = pickle.load(file)
        else:
            #otherwise pull the data from the url
            print(f"Combine year {year} downloaded and saved to file")        
            response = requests.get(url_c)
            with open(download_c, "wb") as file:
                pickle.dump(response, file)                        
                
        bs2 = BeautifulSoup(response.text, "html5lib" )
        df2 = create_combine_df(bs2)
        #print("Combine:", df2.head())           
    else:
        #use alt site
        if os.path.exists(download_c_alt):
            #if html file has already been downloaded, use it
            print(f"ALT Combine year {year} already downloaded; loading from file")
            with open(download_c_alt, "rb") as file:
                response = pickle.load(file)
        else:
            #otherwise pull the data from the url
            print(f"ALT Combine year {year} downloaded and saved to file")        
            response = requests.get(url_c_alt)
            text = response.text
            with open(download_c_alt, "wb") as file:
                pickle.dump(response, file)                        

        #set_trace()
        bs2 = BeautifulSoup(response.text, "html5lib" )
        df2 = create_combine_df_altsite(bs2)
        #print("Combine:", df2.head())                   
    
    #Hall of Fame players have 'HOF' after name
    df1["player"] = df1.player.str.replace('HOF','')
    
    df1["player"] = df1.player.str.strip()
    df1['year'] = str(year)
    df1['playernametolink'] = df1.player.str.lower()
    
    df2["player"] = df2.player.str.strip()
    df2['playernametolink'] = df2.player.str.lower()
    
    if year >= 2000:
        #set_trace()
        #d_and_c = pd.merge(df1, df2, how="left", on = ["player_link"])
        d_and_c = pd.merge(df1, df2, how="left", on = ["playernametolink", 'year'])
    else:
        d_and_c = pd.merge(df1, df2, how="left", on = ["playernametolink", 'year'])

    d_and_c['height_in'] = d_and_c.height.map(convertHeighttoIn)   
                            
    d_and_c['DraftYr'] = year

    dflist.append(d_and_c) 
    
players = pd.concat(dflist)
players.head()
# Out:
# Year: 1990
# Draft year 1990 already downloaded; loading from file
# ALT Combine year 1990 already downloaded; loading from file
# Year: 1991
# Draft year 1991 already downloaded; loading from file
# ALT Combine year 1991 already downloaded; loading from file
# Year: 1992
# Draft year 1992 already downloaded; loading from file
# ALT Combine year 1992 already downloaded; loading from file
# Year: 1993
# Draft year 1993 already downloaded; loading from file
# ALT Combine year 1993 already downloaded; loading from file
# Year: 1994
# Draft year 1994 already downloaded; loading from file
# ALT Combine year 1994 already downloaded; loading from file
# Year: 1995
# Draft year 1995 already downloaded; loading from file
# ALT Combine year 1995 already downloaded; loading from file
# Year: 1996
# Draft year 1996 already downloaded; loading from file
# ALT Combine year 1996 already downloaded; loading from file
# Year: 1997
# Draft year 1997 already downloaded; loading from file
# ALT Combine year 1997 already downloaded; loading from file
# Year: 1998
# Draft year 1998 already downloaded; loading from file
# ALT Combine year 1998 already downloaded; loading from file
# Year: 1999
# Draft year 1999 already downloaded; loading from file
# ALT Combine year 1999 already downloaded; loading from file
# Year: 2000
# Draft year 2000 already downloaded; loading from file
# Combine year 2000 already downloaded; loading from file
# Year: 2001
# Draft year 2001 already downloaded; loading from file
# Combine year 2001 already downloaded; loading from file
# Year: 2002
# Draft year 2002 already downloaded; loading from file
# Combine year 2002 already downloaded; loading from file
# Year: 2003
# Draft year 2003 already downloaded; loading from file
# Combine year 2003 already downloaded; loading from file
# Year: 2004
# Draft year 2004 already downloaded; loading from file
# Combine year 2004 already downloaded; loading from file
# Year: 2005
# Draft year 2005 already downloaded; loading from file
# Combine year 2005 already downloaded; loading from file
# Year: 2006
# Draft year 2006 already downloaded; loading from file
# Combine year 2006 already downloaded; loading from file
# Year: 2007
# Draft year 2007 already downloaded; loading from file
# Combine year 2007 already downloaded; loading from file
# Year: 2008
# Draft year 2008 already downloaded; loading from file
# Combine year 2008 already downloaded; loading from file
# Year: 2009
# Draft year 2009 already downloaded; loading from file
# Combine year 2009 already downloaded; loading from file
# Year: 2010
# Draft year 2010 already downloaded; loading from file
# Combine year 2010 already downloaded; loading from file
#   draft_round draft_pick team        player_x pos_x age year_max    g  \
# 0           1          1  IND     Jeff George    QB  22     2001  131
# 1           1          2  NYJ    Blair Thomas    RB  22     1995   64
# 2           1          3  SEA  Cortez Kennedy    DT  22     2000  167
# 3           1          4  TAM   Keith McCants    DE  22     1995   88
# 4           1          5  SDG     Junior Seau    LB  21     2009  268
#
#    college_id              player_link  ... forty_yd bench_reps vertical  \
# 0    Illinois  /players/G/GeorJe00.htm  ...      NaN        NaN      NaN
# 1    Penn St.  /players/T/ThomBl00.htm  ...      NaN        NaN      NaN
# 2  Miami (FL)  /players/K/KennCo00.htm  ...     4.95         23
# 3     Alabama  /players/M/McCaKe21.htm  ...      NaN        NaN      NaN
# 4         USC  /players/S/SeauJu00.htm  ...      NaN        NaN      NaN
#
#   broad_jump shuttle  cone height_in DraftYr player_link_x player_link_y
# 0        NaN     NaN   NaN         0    1990           NaN           NaN
# 1        NaN     NaN   NaN         0    1990           NaN           NaN
# 2               9.99  9.99         0    1990           NaN           NaN
# 3        NaN     NaN   NaN         0    1990           NaN           NaN
# 4        NaN     NaN   NaN         0    1990           NaN           NaN
#
# [5 rows x 29 columns]

# %%
players.rename(columns={'player_x':'player'}, inplace=True)

# %%
players.drop(columns=['player_y'], inplace=True)

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5493 entries, 0 to 253
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   draft_round       5493 non-null   object
#  1   draft_pick        5493 non-null   object
#  2   team              5493 non-null   object
#  3   player            5493 non-null   object
#  4   pos_x             5493 non-null   object
#  5   age               5493 non-null   object
#  6   year_max          5493 non-null   object
#  7   g                 5493 non-null   object
#  8   college_id        5493 non-null   object
#  9   player_link       2691 non-null   object
#  10  college_link      5493 non-null   object
#  11  year              5493 non-null   object
#  12  playernametolink  5493 non-null   object
#  13  school_name       4369 non-null   object
#  14  pos_y             4369 non-null   object
#  15  height            4369 non-null   object
#  16  weight            4369 non-null   object
#  17  wonderlic         2049 non-null   object
#  18  forty_yd          4369 non-null   object
#  19  bench_reps        4369 non-null   object
#  20  vertical          4369 non-null   object
#  21  broad_jump        4369 non-null   object
#  22  shuttle           4369 non-null   object
#  23  cone              4369 non-null   object
#  24  height_in         5493 non-null   int64
#  25  DraftYr           5493 non-null   int64
#  26  player_link_x     2802 non-null   object
#  27  player_link_y     2320 non-null   object
# dtypes: int64(2), object(26)
# memory usage: 1.2+ MB

# %%
players.DraftYr.value_counts(dropna = False)
# Out:
# 1992    339
# 1991    336
# 1990    332
# 2003    262
# 2002    260
# 2005    258
# 2007    255
# 2009    255
# 1996    255
# 2000    254
# 2010    254
# 2006    254
# 2004    254
# 1999    252
# 2008    251
# 1995    248
# 2001    245
# 1997    241
# 1998    240
# 1993    227
# 1994    221
# Name: DraftYr, dtype: int64

# %%
players.sample(30)
# Out:
#     draft_round draft_pick team             player_x pos_x age year_max    g  \
# 103           4        103  PIT        Adrian Cooper    TE  23     1996   77
# 190           6        188  HOU           C.C. Brown    DB  22     2011   83
# 50            2         51  DEN       Allen Aldridge    LB  22     2001  128
# 85            3         86  PHI  Daniel Te'o-Nesheim    DE  23     2013   39
# 1             1          2  OAK       Robert Gallery     T  24     2011  104
# 231           7        231  OAK        Clifton Black    DB
# 184           7        183  NOR          Scott Hough     G
# 105           4        106  MIN       Antonio Wilson    LB  22     2002   16
# 40            2         41  GNB      Robert Ferguson    WR  21     2008   83
# 188           6        189  SEA        Tyler Schmitt    LB  22
# 272          10        269  SFO       Corey Mayfield    DT  22     1995   27
# 22            1         23  BUF       Antowain Smith    RB  25     2005  131
# 218           7        219  ATL         Kynan Forney     G  22     2009   98
# 206           7        207  CLE           Madre Hill    RB  23     2002    7
# 86            3         87  DEN       Reggie Hayward    DE  22     2009   92
# 146           5        147  CLE          Mike Miller    WR
# 198           6        199  MIN        Antico Dalton    LB  23     2000    5
# 133           5        134  ATL       Anthony Midget    DB
# 108           4        109  CIN        Travis Dorsch     P  22     2002    1
# 43            2         44  NOR          Ray Zellars    RB  22     1998   48
# 105           4        106  ARI        Chris Dishman     G  23     2004   98
# 144           5        145  STL   Jerametrius Butler    DB  22     2007   70
# 118           4        119  PHI            Dave Barr    QB  23     1995    2
# 75            3         76  DET         DeAndre Levy    LB  22     2016   95
# 324          12        323  CLE         Kerry Simien    WR
# 42            2         43  SDG          Isaac Davis     G  22     1997   58
# 15            1         16  TEN          Kevin Dyson    WR  23     2003   59
# 197           6        198  NYG        Andre Woodson    QB  24
# 120           5        119  GNB        Dexter McNabb    FB  23     1995   33
# 115           5        114  RAM         Chris Crooms    DB  23     1992   16
#
#                college_id              player_link  ... forty_yd bench_reps  \
# 103              Oklahoma  /players/C/CoopAd00.htm  ...     4.94         19
# 190             Louisiana                      NaN  ...      NaN        NaN
# 50                Houston  /players/A/AldrAl21.htm  ...     4.61         28
# 85             Washington                      NaN  ...     4.73         29
# 1                    Iowa                      NaN  ...     4.98         24
# 231             Texas St.                      NaN  ...      NaN        NaN
# 184                 Maine                           ...      NaN        NaN
# 105    Texas A&M-Commerce                      NaN  ...     4.56         11
# 40              Texas A&M                      NaN  ...     4.48
# 188         San Diego St.                      NaN  ...     4.93         21
# 272              Oklahoma  /players/M/MayfCo20.htm  ...     5.21         18
# 22                Houston  /players/S/SmitAn00.htm  ...     4.48         15
# 218                Hawaii                      NaN  ...     5.28         23
# 206              Arkansas  /players/H/HillMa20.htm  ...     4.52         20
# 86               Iowa St.                      NaN  ...     4.91         21
# 146            Notre Dame                           ...     4.57
# 198               Hampton  /players/D/DaltAn20.htm  ...     4.76         30
# 133         Virginia Tech                      NaN  ...      NaN        NaN
# 108                Purdue                      NaN  ...     4.89
# 43             Notre Dame  /players/Z/ZellRa00.htm  ...     9.99
# 105              Nebraska  /players/D/DishCh20.htm  ...     5.52         22
# 144            Kansas St.                      NaN  ...     4.57         11
# 118            California  /players/B/BarrDa20.htm  ...     9.99
# 75              Wisconsin                      NaN  ...     4.56         19
# 324  Texas A&M-Kingsville                           ...      NaN        NaN
# 42               Arkansas  /players/D/DaviIs20.htm  ...     5.28         23
# 15                   Utah  /players/D/DysoKe00.htm  ...     9.99
# 197              Kentucky                      NaN  ...     4.85
# 120               Florida  /players/M/McNaDe20.htm  ...     4.71         21
# 115             Texas A&M  /players/C/CrooCh20.htm  ...     4.56         11
#
#     vertical broad_jump shuttle  cone height_in DraftYr  \
# 103     31.5        110    4.67  9.99         0    1991
# 190      NaN        NaN     NaN   NaN         0    2005
# 50      36.5        121    4.35  9.99         0    1994
# 85      37.0        121    4.18  6.91        75    2010
# 1       30.0        105    4.38  7.42        79    2004
# 231      NaN        NaN     NaN   NaN         0    2000
# 184      NaN        NaN     NaN   NaN         0    1990
# 105                                          74    2000
# 40      36.5        120    4.07  7.24        73    2001
# 188     29.0        118    4.33  7.03        74    2008
# 272     25.5        103    4.64  9.99         0    1992
# 22      36.5        117    9.99  9.99         0    1997
# 218     27.0         97    4.70  8.56        74    2001
# 206     32.0        109    4.31  6.90         0    1999
# 86      41.0        127    4.43  7.43        77    2001
# 146     32.5        113    4.19  9.99         0    1995
# 198     35.0        113    4.32  7.49         0    1999
# 133      NaN        NaN     NaN   NaN         0    2000
# 108                                          78    2002
# 43                         9.99  9.99         0    1995
# 105     27.0         93    9.99  9.99         0    1997
# 144     36.0        121    4.40  7.22        70    2001
# 118                        9.99  9.99         0    1995
# 75                  119                      74    2009
# 324      NaN        NaN     NaN   NaN         0    1990
# 42      26.0        104    4.66  9.99         0    1994
# 15                         9.99  9.99         0    1998
# 197                                          76    2008
# 120     34.0        115    4.45  9.99         0    1992
# 115     34.0        121    4.06  9.99         0    1992
#
#                player_link_x            player_link_y
# 103                      NaN                      NaN
# 190  /players/B/BrowC.20.htm                      NaN
# 50                       NaN                      NaN
# 85   /players/T/Teo-Da99.htm  /players/T/Teo-Da99.htm
# 1    /players/G/GallRo20.htm  /players/G/GallRo20.htm
# 231                                               NaN
# 184                      NaN                      NaN
# 105  /players/W/WilsAn20.htm  /players/W/WilsAn20.htm
# 40   /players/F/FergRo00.htm  /players/F/FergRo00.htm
# 188  /players/S/SchmTy99.htm  /players/S/SchmTy99.htm
# 272                      NaN                      NaN
# 22                       NaN                      NaN
# 218  /players/F/FornKy20.htm  /players/F/FornKy20.htm
# 206                      NaN                      NaN
# 86   /players/H/HaywRe20.htm  /players/H/HaywRe20.htm
# 146                      NaN                      NaN
# 198                      NaN                      NaN
# 133                                               NaN
# 108  /players/D/DorsTr20.htm  /players/D/DorsTr20.htm
# 43                       NaN                      NaN
# 105                      NaN                      NaN
# 144  /players/B/ButlJe20.htm  /players/B/ButlJe20.htm
# 118                      NaN                      NaN
# 75   /players/L/LevyDe99.htm  /players/L/LevyDe99.htm
# 324                      NaN                      NaN
# 42                       NaN                      NaN
# 15                       NaN                      NaN
# 197  /players/W/WoodAn00.htm  /players/W/WoodAn00.htm
# 120                      NaN                      NaN
# 115                      NaN                      NaN
#
# [30 rows x 29 columns]

# %%
df2.player_link.nunique()
# Out:
# 221

# %%
df2.sort_values('player_link')
# Out:
#                  player              player_link  pos         school_name  \
# 207     Richard Mercier                            OG          Miami (FL)
# 323       Destry Wright                            RB       Jackson State
# 75           Adam Davis                            OG      Oklahoma State
# 74         Darren Davis                            RB          Iowa State
# 73   Joe Dean Davenport                            TE            Arkansas
# ..                  ...                      ...  ...                 ...
# 321      Antonio Wilson  /players/W/WilsAn20.htm  OLB  Texas A&M-Commerce
# 322      Cedric Woodard  /players/W/WoodCe20.htm   DT               Texas
# 324        Spergon Wynn  /players/W/WynnSp00.htm   QB         Texas State
# 325       Bashir Yamini  /players/Y/YamiBa20.htm   WR                Iowa
# 326         Brian Young  /players/Y/YounBr20.htm   DE       Texas-El Paso
#
#     height weight forty_yd vertical bench_reps broad_jump  cone shuttle  year  \
# 207    6-3    295     5.39     26.0         18         97  7.84    4.78  2000
# 323   5-11    216     4.84     29.5         15        112  7.15    4.41  2000
# 75     6-4    309     5.66     26.0                    92  8.51    5.00  2000
# 74     5-8    189     4.81     32.0         13        109  7.04    4.47  2000
# 73     6-7    268     5.06     30.0         13        108  7.33    4.67  2000
# ..     ...    ...      ...      ...        ...        ...   ...     ...   ...
# 321    6-2    245     4.56                  11                           2000
# 322    6-2    290     5.21     30.5         23        109                2000
# 324    6-3    229     4.91     34.0                   108  7.71    4.59  2000
# 325    6-3    191     4.53     33.0                   130  7.09    4.18  2000
# 326    6-2    278     4.94     29.5         27        106  7.20    4.47  2000
#
#        playernametolink
# 207     richard mercier
# 323       destry wright
# 75           adam davis
# 74         darren davis
# 73   joe dean davenport
# ..                  ...
# 321      antonio wilson
# 322      cedric woodard
# 324        spergon wynn
# 325       bashir yamini
# 326         brian young
#
# [327 rows x 14 columns]

# %%
players.to_csv('df/players3.csv')

# %%
# !pwd
# Out:
# /Users/jmichit/Documents/Metis/linear_regression

# %% [markdown]
# ## Import College stats

# %%
debug
# Out:
# > /opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/generic.py(1684)_get_label_or_level_values()
#    1682             values = self.axes[axis].get_level_values(key)._values
#    1683         else:
# -> 1684             raise KeyError(key)
#    1685
#    1686         # Check for duplicates
#
# ipdb> ll
#    1640     @final
#    1641     def _get_label_or_level_values(self, key: str, axis: int = 0) -> np.ndarray:
#    1642         """
#    1643         Return a 1-D array of values associated with `key`, a label or level
#    1644         from the given `axis`.
#    1645
#    1646         Retrieval logic:
#    1647           - (axis=0): Return column values if `key` matches a column label.
#    1648             Otherwise return index level values if `key` matches an index
#    1649             level.
#    1650           - (axis=1): Return row values if `key` matches an index label.
#    1651             Otherwise return column level values if 'key' matches a column
#    1652             level
#    1653
#    1654         Parameters
#    1655         ----------
#    1656         key: str
#    1657             Label or level name.
#    1658         axis: int, default 0
#    1659             Axis that levels are associated with (0 for index, 1 for columns)
#    1660
#    1661         Returns
#    1662         -------
#    1663         values: np.ndarray
#    1664
#    1665         Raises
#    1666         ------
#    1667         KeyError
#    1668             if `key` matches neither a label nor a level
#    1669         ValueError
#    1670             if `key` matches multiple labels
#    1671         FutureWarning
#    1672             if `key` is ambiguous. This will become an ambiguity error in a
#    1673             future version
#    1674         """
#    1675         axis = self._get_axis_number(axis)
#    1676         other_axes = [ax for ax in range(self._AXIS_LEN) if ax != axis]
#    1677
#    1678         if self._is_label_reference(key, axis=axis):
#    1679             self._check_label_or_level_ambiguity(key, axis=axis)
#    1680             values = self.xs(key, axis=other_axes[0])._values
#    1681         elif self._is_level_reference(key, axis=axis):
#    1682             values = self.axes[axis].get_level_values(key)._values
#    1683         else:
# -> 1684             raise KeyError(key)
#    1685
#    1686         # Check for duplicates
#    1687         if values.ndim > 1:
#    1688
#    1689             if other_axes and isinstance(self._get_axis(other_axes[0]), MultiIndex):
#    1690                 multi_message = (
#    1691                     "\n"
#    1692                     "For a multi-index, the label must be a "
#    1693                     "tuple with elements corresponding to each level."
#    1694                 )
#    1695             else:
#    1696                 multi_message = ""
#    1697
#    1698             label_axis_name = "column" if axis == 0 else "index"
#    1699             raise ValueError(
#    1700                 f"The {label_axis_name} label '{key}' is not unique.{multi_message}"
#    1701             )
#    1702
#    1703         return values
#    1704
# ipdb> up
# > /opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/reshape/merge.py(1033)_get_merge_keys()
#    1031                     if not is_rkey(rk):
#    1032                         if rk is not None:
# -> 1033                             right_keys.append(right._get_label_or_level_values(rk))
#    1034                         else:
#    1035                             # work-around for merge_asof(right_index=True)
#
# ipdb> up
# > /opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/reshape/merge.py(668)__init__()
#     666             self.right_join_keys,
#     667             self.join_names,
# --> 668         ) = self._get_merge_keys()
#     669
#     670         # validate the merge keys dtypes. We may need to coerce
#
# ipdb> up
# > /opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/reshape/merge.py(74)merge()
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ipdb> up
# > <ipython-input-156-4ceced76dc1d>(86)<module>()
#      84     df2["player"] = df2.player.str.strip()
#      85
# ---> 86     d_and_c = pd.merge(df1, df2, how="left", on = ["player", 'year'])
#      87
#      88     d_and_c['height_in'] = d_and_c.height.map(convertHeighttoIn)
#
# ipdb> up
# *** Oldest frame
# ipdb> quit

# %%
# url = "https://www.sports-reference.com/cfb/players/kion-wilson-1.html"

# response = requests.get(url)

# bs3 = BeautifulSoup(response.text)

# %%
def get_college_data(bs_obj, debug = False):
    #set_trace()
    tbl = bs_obj.find("table", class_="stats_table")
    
    #No tbl available so return {}
    if tbl is None:
        return {}
    
    rows = tbl.find_all("tr", attrs = {"class":False})

    games = 0
    seasons = 0

    conf = ""

    for row in rows[1:]:
        seasons += 1
        x = row.find('td', attrs = {"data-stat":"g"})
        
        if x.text.isnumeric():
            games += int(x.text)
        
        cname = row.find('td', attrs = {'data-stat':"school_name"}).text
        cname_link = row.find('td', attrs = {'data-stat':"school_name"}).a.get('href')
        conf = row.find('td', attrs = {'data-stat':"conf_abbr"}).text    

    if debug:
        print("College Conference:  {}".format(conf))    
        print("College Name:        {}".format(cname))    
        print("Cname link {}".format(cname_link))
        print("College Seasons:     {}".format(seasons))
        print("College Games:       {}".format(games))

    odict = {"conf" : conf,
             "cname" : cname,
             "cname_link" : cname_link,
             "cseasons" : seasons,
             "cgames" : games}
    
    return odict

# %%
def process_player_file(name, url, filestr):

    if os.path.exists(filestr):
        #if html file has already been downloaded, use it
        print(f"Player {name} already downloaded; loading from file")
        with open(filestr, "rb") as file:
            response = pickle.load(file)
    else:
        #otherwise pull the data from the url
        print(f"Player {name} downloaded and saved to file")        
        response = requests.get(url)
        with open(filestr, "wb") as file:
            pickle.dump(response, file)                        
         
    bs = BeautifulSoup(response.text, "html5lib" )
    data = get_college_data(bs)
    
    return data

# %%
def load_cdat_by_draftyr(year):
    base_pkl = f"players/{year}/"

    ls_college =[]

    for i, row in players[players.DraftYr == year].iterrows():
        link = row.college_link
        name = row.player
        plink = row.player_link
        filestr = base_pkl + os.path.basename(link).replace('.html','.pkl')  

        cdat = {}
        if link.strip() != '':      
            cdat = process_player_file(name, link, filestr)

        cdat["player"] = name
        cdat["year"] = year
        cdat["clink"] = link
        cdat["plink"] = row.player_link

        ls_college.append(cdat)

    return pd.DataFrame(ls_college)

# %%
draft_ls = []

for year in range(1990,2011):
    print(f"***{year}***")
    df_coll = load_cdat_by_draftyr(year)
    draft_ls.append(df_coll)
    
collegedf = pd.concat(draft_ls)

#collegedf.to_csv('collegedf2.csv')

collegedf.head()
# Out:
# ***1990***
# Player Jeff George already downloaded; loading from file
# Player Blair Thomas already downloaded; loading from file
# Player Keith McCants already downloaded; loading from file
# Player Junior Seau already downloaded; loading from file
# Player Mark Carrier already downloaded; loading from file
# Player Andre Ware already downloaded; loading from file
# Player Chris Singleton already downloaded; loading from file
# Player James Francis already downloaded; loading from file
# Player Percy Snow already downloaded; loading from file
# Player Emmitt Smith already downloaded; loading from file
# Player Darrell Thompson already downloaded; loading from file
# Player Steve Broussard already downloaded; loading from file
# Player Ben Smith already downloaded; loading from file
# Player Rodney Hampton already downloaded; loading from file
# Player Dexter Carter already downloaded; loading from file
# Player Alexander Wright already downloaded; loading from file
# Player Reggie Rembert already downloaded; loading from file
# Player Terry Wooden already downloaded; loading from file
# Player Reggie Cobb already downloaded; loading from file
# Player Anthony Thompson already downloaded; loading from file
# Player Ron Cox already downloaded; loading from file
# Player Robert Blackmon already downloaded; loading from file
# Player Anthony Johnson already downloaded; loading from file
# Player Harold Green already downloaded; loading from file
# Player Jeff Alm already downloaded; loading from file
# Player Carwell Gardner already downloaded; loading from file
# Player Kenny Davidson already downloaded; loading from file
# Player Leroy Hoard already downloaded; loading from file
# Player Andre Collins already downloaded; loading from file
# Player Dennis Brown already downloaded; loading from file
# Player LeRoy Butler already downloaded; loading from file
# Player Pat Terrell already downloaded; loading from file
# Player Mike Bellamy already downloaded; loading from file
# Player Alton Montgomery already downloaded; loading from file
# Player Mike Jones already downloaded; loading from file
# Player Ricky Proehl already downloaded; loading from file
# Player Tom Hodson already downloaded; loading from file
# Player Tim Ryan already downloaded; loading from file
# Player Peter Tom Willis already downloaded; loading from file
# Player Bernard Clark already downloaded; loading from file
# Player Walter Wilson already downloaded; loading from file
# Player Ron Lewis already downloaded; loading from file
# Player Neil O'Donnell already downloaded; loading from file
# Player Joel Smeenge already downloaded; loading from file
# Player Bobby Houston already downloaded; loading from file
# Player Mohammed Elewonibi already downloaded; loading from file
# Player Latin Berry already downloaded; loading from file
# Player Greg Mark already downloaded; loading from file
# Player Greg McMurtry already downloaded; loading from file
# Player Stacey Simmons already downloaded; loading from file
# Player Troy Taylor already downloaded; loading from file
# Player Cary Conklin already downloaded; loading from file
# Player Jesse Anderson already downloaded; loading from file
# Player Tony Moss already downloaded; loading from file
# Player Chris Warren already downloaded; loading from file
# Player Scott Mitchell already downloaded; loading from file
# Player Torin Dorn already downloaded; loading from file
# Player Chris Calloway already downloaded; loading from file
# Player Eric Still already downloaded; loading from file
# Player Eddie Fuller already downloaded; loading from file
# Player Harlon Barnett already downloaded; loading from file
# Player Alan Grant already downloaded; loading from file
# Player Alonzo Hampton already downloaded; loading from file
# Player Chris Oldham already downloaded; loading from file
# Player Rico Labbe already downloaded; loading from file
# Player Junior Robinson already downloaded; loading from file
# Player Reggie Thornton already downloaded; loading from file
# Player Pat Chaffey already downloaded; loading from file
# Player Jeff Campbell already downloaded; loading from file
# Player James Gray already downloaded; loading from file
# Player Lynn James already downloaded; loading from file
# Player Charles Arbuckle already downloaded; loading from file
# Player Ken Hackemack already downloaded; loading from file
# Player Barry Foster already downloaded; loading from file
# Player Cedric Smith already downloaded; loading from file
# Player Charles Wilson already downloaded; loading from file
# Player Calvin Williams already downloaded; loading from file
# Player Robert McWright already downloaded; loading from file
# Player Le-Lo Lang already downloaded; loading from file
# Player Leroy Holt already downloaded; loading from file
# Player Mike Pringle already downloaded; loading from file
# Player Terance Mathis already downloaded; loading from file
# Player Derrick Douglas already downloaded; loading from file
# Player John Mangum already downloaded; loading from file
# Player Ned Bolcar already downloaded; loading from file
# Player Maurice Henry already downloaded; loading from file
# Player Marcus Wilson already downloaded; loading from file
# Player Tony Jones already downloaded; loading from file
# Player John Nies already downloaded; loading from file
# Player Ronald Heard already downloaded; loading from file
# Player Tim Stallworth already downloaded; loading from file
# Player Kevin Thompson already downloaded; loading from file
# Player Derrick Walker already downloaded; loading from file
# Player Ronnie Haliburton already downloaded; loading from file
# Player Basil Proctor already downloaded; loading from file
# Player Johnny Johnson already downloaded; loading from file
# Player Bob Kula already downloaded; loading from file
# Player Craig Ogletree already downloaded; loading from file
# Player Scott Galbraith already downloaded; loading from file
# Player Dan Grayson already downloaded; loading from file
# Player Andy Murray already downloaded; loading from file
# Player Nate Lewis already downloaded; loading from file
# Player Kent Elmore already downloaded; loading from file
# Player Aaron Emanuel already downloaded; loading from file
# Player Willie Green already downloaded; loading from file
# Player Mickey Washington already downloaded; loading from file
# Player James Rouse already downloaded; loading from file
# Player J.J. Flannigan already downloaded; loading from file
# Player Bill Hitchcock already downloaded; loading from file
# Player Doug Wellsandt already downloaded; loading from file
# Player Thomas Woods already downloaded; loading from file
# Player Ken Clark already downloaded; loading from file
# Player Gerry Gdowski already downloaded; loading from file
# Player Marvcus Patton already downloaded; loading from file
# Player Brett Tucker already downloaded; loading from file
# Player Jock Jones already downloaded; loading from file
# Player Roger Brown already downloaded; loading from file
# Player Dwight Pickens already downloaded; loading from file
# Player Dale Dawkins already downloaded; loading from file
# Player David Bavaro already downloaded; loading from file
# Player Leon Perry already downloaded; loading from file
# Player Phil Ross already downloaded; loading from file
# Player Mitchell Price already downloaded; loading from file
# Player Michael Owens already downloaded; loading from file
# Player Pat Coleman already downloaded; loading from file
# Player Clarkston Hines already downloaded; loading from file
# Player Gary Jones already downloaded; loading from file
# Player Eugene Rowell already downloaded; loading from file
# Player Terry Allen already downloaded; loading from file
# Player Tony Lomack already downloaded; loading from file
# Player Todd Ellis already downloaded; loading from file
# Player Pat Newman already downloaded; loading from file
# Player Brad Quast already downloaded; loading from file
# Player Mike Busch already downloaded; loading from file
# Player Kenny Berry already downloaded; loading from file
# Player Gary Cooper already downloaded; loading from file
# Player D'Juan Francisco already downloaded; loading from file
# Player Craig Hudson already downloaded; loading from file
# Player Mike Lodish already downloaded; loading from file
# Player Eddie Miles already downloaded; loading from file
# Player Ernest Spears already downloaded; loading from file
# Player Anthony Thompson already downloaded; loading from file
# Player Chris Ellison already downloaded; loading from file
# Player Derrick Kelson already downloaded; loading from file
# Player Terry Anthony already downloaded; loading from file
# Player Tommie Stowers already downloaded; loading from file
# Player Reginald Warnsley already downloaded; loading from file
# Player Daryl Reed already downloaded; loading from file
# Player Carnel Smith already downloaded; loading from file
# Player John Hudson already downloaded; loading from file
# Player Tim Downing already downloaded; loading from file
# Player Myron Jones already downloaded; loading from file
# Player Shawn McCarthy already downloaded; loading from file
# Player Darrell Davis already downloaded; loading from file
# Player Donnie Riley already downloaded; loading from file
# Player Ventson Donelson already downloaded; loading from file
# Player Anthony Cooney already downloaded; loading from file
# Player John Gromos already downloaded; loading from file
# Player Robert Claiborne already downloaded; loading from file
# Player Andre Riley already downloaded; loading from file
# Player Bobby Harden already downloaded; loading from file
# Player Dean Brown already downloaded; loading from file
# Player Major Harris already downloaded; loading from file
# Player Tony Jeffery already downloaded; loading from file
# Player Richard Bell already downloaded; loading from file
# Player Reggie Slack already downloaded; loading from file
# Player Ron Goetz already downloaded; loading from file
# Player Kirk Maggio already downloaded; loading from file
# Player Ken McMichel already downloaded; loading from file
# ***1991***
# Player Russell Maryland already downloaded; loading from file
# Player Eric Turner already downloaded; loading from file
# Player Bruce Pickens already downloaded; loading from file
# Player Todd Lyght already downloaded; loading from file
# Player Antone Davis already downloaded; loading from file
# Player Stanley Richard already downloaded; loading from file
# Player Herman Moore already downloaded; loading from file
# Player Alvin Harper already downloaded; loading from file
# Player Mike Pritchard already downloaded; loading from file
# Player Leonard Russell already downloaded; loading from file
# Player Dan McGwire already downloaded; loading from file
# Player Alfred Williams already downloaded; loading from file
# Player Vinnie Clark already downloaded; loading from file
# Player Kelvin Pritchett already downloaded; loading from file
# Player Harvey Williams already downloaded; loading from file
# Player Randal Hill already downloaded; loading from file
# Player Todd Marinovich already downloaded; loading from file
# Player Henry Jones already downloaded; loading from file
# Player Jarrod Bunch already downloaded; loading from file
# Player Mike Dumas already downloaded; loading from file
# Player Ed King already downloaded; loading from file
# Player Reggie Johnson already downloaded; loading from file
# Player Reggie Johnson already downloaded; loading from file
# Player Roman Phifer already downloaded; loading from file
# Player Brett Favre already downloaded; loading from file
# Player Browning Nagle already downloaded; loading from file
# Player Darryll Lewis already downloaded; loading from file
# Player Eric Bieniemy already downloaded; loading from file
# Player Jerome Henderson already downloaded; loading from file
# Player Wesley Carroll already downloaded; loading from file
# Player Nick Bell already downloaded; loading from file
# Player John Flannery already downloaded; loading from file
# Player Ricky Watters already downloaded; loading from file
# Player Jeff Graham already downloaded; loading from file
# Player Chris Zorich already downloaded; loading from file
# Player Doug Thomas already downloaded; loading from file
# Player John Johnson already downloaded; loading from file
# Player Reggie Barrett already downloaded; loading from file
# Player Aaron Craver already downloaded; loading from file
# Player Godfrey Myles already downloaded; loading from file
# Player Mo Lewis already downloaded; loading from file
# Player Carlos Jenkins already downloaded; loading from file
# Player Lawrence Dawsey already downloaded; loading from file
# Player Dave McCloughan already downloaded; loading from file
# Player Steve Jackson already downloaded; loading from file
# Player Ernie Mills already downloaded; loading from file
# Player David Daniels already downloaded; loading from file
# Player Ricky Ervins already downloaded; loading from file
# Player Chris Gardocki already downloaded; loading from file
# Player Robert Wilson already downloaded; loading from file
# Player Chuck Webb already downloaded; loading from file
# Player Ed McCaffrey already downloaded; loading from file
# Player Scott Zolak already downloaded; loading from file
# Player Dexter Davis already downloaded; loading from file
# Player Moe Gardner already downloaded; loading from file
# Player Sammy Walker already downloaded; loading from file
# Player Derek Russell already downloaded; loading from file
# Player Randy Baldwin already downloaded; loading from file
# Player Tony Covington already downloaded; loading from file
# Player Mitch Donahue already downloaded; loading from file
# Player Curvin Richards already downloaded; loading from file
# Player John Kasay already downloaded; loading from file
# Player Donald Hollas already downloaded; loading from file
# Player Rocket Ismail already downloaded; loading from file
# Player David Rocker already downloaded; loading from file
# Player Marcus Robertson already downloaded; loading from file
# Player Adrian Cooper already downloaded; loading from file
# Player Joe Johnson already downloaded; loading from file
# Player Bill Musgrave already downloaded; loading from file
# Player Robert Bailey already downloaded; loading from file
# Player Rob Carpenter already downloaded; loading from file
# Player Jon Vaughn already downloaded; loading from file
# Player Greg Lewis already downloaded; loading from file
# Player Robert Young already downloaded; loading from file
# Player Merton Hanks already downloaded; loading from file
# Player Duane Young already downloaded; loading from file
# Player Kerry Cash already downloaded; loading from file
# Player Reggie Jones already downloaded; loading from file
# Player Harlan Davis already downloaded; loading from file
# Player Gary Wellman already downloaded; loading from file
# Player Craig Erickson already downloaded; loading from file
# Player Darrick Brownlow already downloaded; loading from file
# Player Charles Mincy already downloaded; loading from file
# Player Anthony Morgan already downloaded; loading from file
# Player Jeff Fite already downloaded; loading from file
# Player Shawn Wilbourn already downloaded; loading from file
# Player Michael Jackson already downloaded; loading from file
# Player Neal Fort already downloaded; loading from file
# Player Blaise Bryant already downloaded; loading from file
# Player Richie Andrews already downloaded; loading from file
# Player Richard Fain already downloaded; loading from file
# Player Leroy Thompson already downloaded; loading from file
# Player Dennis Ransom already downloaded; loading from file
# Player Mike Riley already downloaded; loading from file
# Player Darren Lewis already downloaded; loading from file
# Player Joe Garten already downloaded; loading from file
# Player Frank Blevins already downloaded; loading from file
# Player Brian Mitchell already downloaded; loading from file
# Player Calvin Tiggle already downloaded; loading from file
# Player Reggie Burnette already downloaded; loading from file
# Player Tripp Welborne already downloaded; loading from file
# Player James Bradley already downloaded; loading from file
# Player James Joseph already downloaded; loading from file
# Player Keith Cash already downloaded; loading from file
# Player Paul Justin already downloaded; loading from file
# Player Sheldon Canley already downloaded; loading from file
# Player Simmie Carter already downloaded; loading from file
# Player Harry Colon already downloaded; loading from file
# Player Greg Amsler already downloaded; loading from file
# Player Randy Austin already downloaded; loading from file
# Player Tim James already downloaded; loading from file
# Player Johnny Walker already downloaded; loading from file
# Player Jerry Evans already downloaded; loading from file
# Player Cedric Jackson already downloaded; loading from file
# Player Tim Bruton already downloaded; loading from file
# Player Mike Dingle already downloaded; loading from file
# Player Gary Brown already downloaded; loading from file
# Player Larry Horton already downloaded; loading from file
# Player Roland Smith already downloaded; loading from file
# Player Tony Hargain already downloaded; loading from file
# Player O'Neil Glenn already downloaded; loading from file
# Player Gerald Hudson already downloaded; loading from file
# Player Damon Mays already downloaded; loading from file
# Player Howard Griffith already downloaded; loading from file
# Player Anthony Wallace already downloaded; loading from file
# Player Bruce McGonnigal already downloaded; loading from file
# Player Shawn Wiggins already downloaded; loading from file
# Player Shane Garrett already downloaded; loading from file
# Player Chuck Weatherspoon already downloaded; loading from file
# Player Charles Bell already downloaded; loading from file
# Player Robbie Keen already downloaded; loading from file
# Player Scott Miller already downloaded; loading from file
# Player Scott Miller already downloaded; loading from file
# Player Louis Riddick already downloaded; loading from file
# Player Jerry Bouldin already downloaded; loading from file
# Player Randy Bethel already downloaded; loading from file
# Player Brian Greenfield already downloaded; loading from file
# Player Curtis Mayfield already downloaded; loading from file
# Player Ronald Poles already downloaded; loading from file
# Player Pat O'Hara already downloaded; loading from file
# Player Al Baker already downloaded; loading from file
# Player Frank Giannetti already downloaded; loading from file
# Player Hyland Hickson already downloaded; loading from file
# Player Curtis Moore already downloaded; loading from file
# Player Cris Shale already downloaded; loading from file
# Player Eric Ramsey already downloaded; loading from file
# Player Michael Titley already downloaded; loading from file
# Player Vince Moore already downloaded; loading from file
# Player Nathan LaDuke already downloaded; loading from file
# Player Joe Sims already downloaded; loading from file
# Player Shawn Moore already downloaded; loading from file
# Player Slip Watkins already downloaded; loading from file
# Player Ivan Caesar already downloaded; loading from file
# Player Scott Ross already downloaded; loading from file
# Player Chris Smith already downloaded; loading from file
# Player Efrum Thomas already downloaded; loading from file
# Player Tony Stewart already downloaded; loading from file
# Player Bobby Olive already downloaded; loading from file
# Player Stacy Long already downloaded; loading from file
# Player Bobby Slaughter already downloaded; loading from file
# Player Bob Christian already downloaded; loading from file
# Player Ernie Thompson already downloaded; loading from file
# Player Linzy Collins already downloaded; loading from file
# Player Chris Samuels already downloaded; loading from file
# Player Zeno Alexander already downloaded; loading from file
# Player Larry Brown already downloaded; loading from file
# Player Jeff Brady already downloaded; loading from file
# Player Alex Johnson already downloaded; loading from file
# Player Keenan McCardell already downloaded; loading from file
# Player Stephen Clark already downloaded; loading from file
# ***1992***
# Player Steve Emtman already downloaded; loading from file
# Player Sean Gilbert already downloaded; loading from file
# Player Desmond Howard already downloaded; loading from file
# Player Terrell Buckley already downloaded; loading from file
# Player David Klingler already downloaded; loading from file
# Player Troy Vincent already downloaded; loading from file
# Player Bob Whitfield already downloaded; loading from file
# Player Tommy Vardell already downloaded; loading from file
# Player Derek Brown already downloaded; loading from file
# Player Johnny Mitchell already downloaded; loading from file
# Player Kevin Smith already downloaded; loading from file
# Player Kevin Smith already downloaded; loading from file
# Player Dana Hall already downloaded; loading from file
# Player Tony Smith already downloaded; loading from file
# Player Tony Smith already downloaded; loading from file
# Player Dale Carter already downloaded; loading from file
# Player Vaughn Dunbar already downloaded; loading from file
# Player Chris Mims already downloaded; loading from file
# Player Robert Jones already downloaded; loading from file
# Player Tommy Maddox already downloaded; loading from file
# Player John Fina already downloaded; loading from file
# Player Darryl Williams already downloaded; loading from file
# Player Steve Israel already downloaded; loading from file
# Player Carl Pickens already downloaded; loading from file
# Player Greg Skrepenak already downloaded; loading from file
# Player Marquez Pope already downloaded; loading from file
# Player Rod Smith already downloaded; loading from file
# Player Darren Woodson already downloaded; loading from file
# Player Levon Kirkland already downloaded; loading from file
# Player Matt Blundin already downloaded; loading from file
# Player Phillippi Sparks already downloaded; loading from file
# Player Eddie Blake already downloaded; loading from file
# Player Courtney Hawkins already downloaded; loading from file
# Player Amp Lee already downloaded; loading from file
# Player Tony Sacca already downloaded; loading from file
# Player Siran Stacy already downloaded; loading from file
# Player Patrick Rowe already downloaded; loading from file
# Player Jason Hanson already downloaded; loading from file
# Player Todd Kinchen already downloaded; loading from file
# Player Robert Brooks already downloaded; loading from file
# Player Aaron Pierce already downloaded; loading from file
# Player Kevin Turner already downloaded; loading from file
# Player Tyrone Legette already downloaded; loading from file
# Player Corey Harris already downloaded; loading from file
# Player Tyji Armstrong already downloaded; loading from file
# Player Rodney Culver already downloaded; loading from file
# Player Craig Erickson already downloaded; loading from file
# Player Jeff Christy already downloaded; loading from file
# Player Tony Brooks already downloaded; loading from file
# Player Darren Anderson already downloaded; loading from file
# Player Charles Davenport already downloaded; loading from file
# Player Keo Coleman already downloaded; loading from file
# Player Casey Weldon already downloaded; loading from file
# Player Edgar Bennett already downloaded; loading from file
# Player Sean Lumpkin already downloaded; loading from file
# Player Will Furrer already downloaded; loading from file
# Player Maury Toy already downloaded; loading from file
# Player Rogerick Green already downloaded; loading from file
# Player Dexter McNabb already downloaded; loading from file
# Player Alan Haller already downloaded; loading from file
# Player Michael Wright already downloaded; loading from file
# Player Derrick Hoskins already downloaded; loading from file
# Player Orlando McKay already downloaded; loading from file
# Player Santana Dotson already downloaded; loading from file
# Player Joe Bowden already downloaded; loading from file
# Player Todd Harrison already downloaded; loading from file
# Player Tony Brown already downloaded; loading from file
# Player Matt Darby already downloaded; loading from file
# Player Rico Smith already downloaded; loading from file
# Player Fallon Wacasey already downloaded; loading from file
# Player Michael Bates already downloaded; loading from file
# Player Mike Gaddis already downloaded; loading from file
# Player Roosevelt Collins already downloaded; loading from file
# Player Mark Chmura already downloaded; loading from file
# Player Terry Ray already downloaded; loading from file
# Player Tony Smith already downloaded; loading from file
# Player Tony Smith already downloaded; loading from file
# Player Jeff Sydner already downloaded; loading from file
# Player Mark Berry already downloaded; loading from file
# Player Mario Bailey already downloaded; loading from file
# Player Kary Vincent already downloaded; loading from file
# Player Jeff Blake already downloaded; loading from file
# Player Nate Turner already downloaded; loading from file
# Player Ray Rowe already downloaded; loading from file
# Player Deems May already downloaded; loading from file
# Player Derek Ware already downloaded; loading from file
# Player Russ Campbell already downloaded; loading from file
# Player David Wilson already downloaded; loading from file
# Player Ken Swilling already downloaded; loading from file
# Player Kevin Smith already downloaded; loading from file
# Player Kevin Smith already downloaded; loading from file
# Player Erick Anderson already downloaded; loading from file
# Player Scottie Graham already downloaded; loading from file
# Player Elbert Turner already downloaded; loading from file
# Player Dave Moore already downloaded; loading from file
# Player Jon Bostick already downloaded; loading from file
# Player Calvin Holmes already downloaded; loading from file
# Player Jason Belser already downloaded; loading from file
# Player Anthony McDowell already downloaded; loading from file
# Player Eric Blount already downloaded; loading from file
# Player Darren Perry already downloaded; loading from file
# Player Scott Lockwood already downloaded; loading from file
# Player Sam Gash already downloaded; loading from file
# Player Luke Fisher already downloaded; loading from file
# Player Kent Graham already downloaded; loading from file
# Player Vincent Brownlee already downloaded; loading from file
# Player Bucky Richardson already downloaded; loading from file
# Player Willie Clay already downloaded; loading from file
# Player Mike Pawlawski already downloaded; loading from file
# Player Eddie Miller already downloaded; loading from file
# Player Ostell Miles already downloaded; loading from file
# Player Brad Johnson already downloaded; loading from file
# Player T.J. Rubley already downloaded; loading from file
# Player Ty Detmer already downloaded; loading from file
# Player Tim Hill already downloaded; loading from file
# Player Shazzon Bradley already downloaded; loading from file
# Player Darian Hagan already downloaded; loading from file
# Player Jay Leeuwenburg already downloaded; loading from file
# Player Don Jones already downloaded; loading from file
# Player Mirko Jurkovic already downloaded; loading from file
# Player Bernard Dafney already downloaded; loading from file
# Player Muhammad Oliver already downloaded; loading from file
# Player Chris Walsh already downloaded; loading from file
# Player Boone Powell already downloaded; loading from file
# Player Turner Baur already downloaded; loading from file
# Player Mike Saunders already downloaded; loading from file
# Player Brad Culpepper already downloaded; loading from file
# Player George Rooks already downloaded; loading from file
# Player Mario Johnson already downloaded; loading from file
# Player Raoul Spears already downloaded; loading from file
# Player Jerry Ostroski already downloaded; loading from file
# Player Mark McMillian already downloaded; loading from file
# Player Nikki Fisher already downloaded; loading from file
# Player Dion Johnson already downloaded; loading from file
# Player Steve Gordon already downloaded; loading from file
# Player Tony Barker already downloaded; loading from file
# Player Mazio Royster already downloaded; loading from file
# Player Keith McAfee already downloaded; loading from file
# Player Rob Baxley already downloaded; loading from file
# Player Augustin Olobia already downloaded; loading from file
# Player Lee Miles already downloaded; loading from file
# Player Mark Barsotti already downloaded; loading from file
# Player Tom Covington already downloaded; loading from file
# Player Vince Marrow already downloaded; loading from file
# Player Terry Smith already downloaded; loading from file
# Player Klaus Wilmsmeyer already downloaded; loading from file
# Player Carlos Huerta already downloaded; loading from file
# Player Keithen McCant already downloaded; loading from file
# Player Chico Fraley already downloaded; loading from file
# Player John MacNeill already downloaded; loading from file
# Player Kameno Bell already downloaded; loading from file
# Player Joe Wood already downloaded; loading from file
# Player John Granby already downloaded; loading from file
# Player Matt Rodgers already downloaded; loading from file
# ***1993***
# Player Drew Bledsoe already downloaded; loading from file
# Player Rick Mirer already downloaded; loading from file
# Player Garrison Hearst already downloaded; loading from file
# Player Marvin Jones already downloaded; loading from file
# Player John Copeland already downloaded; loading from file
# Player Eric Curry already downloaded; loading from file
# Player Curtis Conway already downloaded; loading from file
# Player Willie Roaf already downloaded; loading from file
# Player Lincoln Kennedy already downloaded; loading from file
# Player Jerome Bettis already downloaded; loading from file
# Player Patrick Bates already downloaded; loading from file
# Player Sean Dawkins already downloaded; loading from file
# Player Tom Carter already downloaded; loading from file
# Player Irv Smith already downloaded; loading from file
# Player Robert Smith already downloaded; loading from file
# Player Darrien Gordon already downloaded; loading from file
# Player Deon Figures already downloaded; loading from file
# Player Leonard Renfro already downloaded; loading from file
# Player O.J. McDuffie already downloaded; loading from file
# Player George Teague already downloaded; loading from file
# Player Carlton Gray already downloaded; loading from file
# Player Chris Slade already downloaded; loading from file
# Player Ryan McNeil already downloaded; loading from file
# Player Tony McGee already downloaded; loading from file
# Player Roger Harper already downloaded; loading from file
# Player Troy Drayton already downloaded; loading from file
# Player Natrone Means already downloaded; loading from file
# Player Glyn Milburn already downloaded; loading from file
# Player Reggie Brooks already downloaded; loading from file
# Player Kevin Williams already downloaded; loading from file
# Player Kevin Williams already downloaded; loading from file
# Player Micheal Barrow already downloaded; loading from file
# Player Victor Bailey already downloaded; loading from file
# Player Qadry Ismail already downloaded; loading from file
# Player Darrin Smith already downloaded; loading from file
# Player John Gerak already downloaded; loading from file
# Player Billy Joe Hobert already downloaded; loading from file
# Player Steve Tovar already downloaded; loading from file
# Player Lamar Thomas already downloaded; loading from file
# Player Chris Gedney already downloaded; loading from file
# Player Ray Buchanan already downloaded; loading from file
# Player Marcus Buckley already downloaded; loading from file
# Player Mike Compton already downloaded; loading from file
# Player Jason Elam already downloaded; loading from file
# Player James Trapp already downloaded; loading from file
# Player Russell White already downloaded; loading from file
# Player Will Shields already downloaded; loading from file
# Player Andre Hastings already downloaded; loading from file
# Player Mike Reid already downloaded; loading from file
# Player Terry Kirby already downloaded; loading from file
# Player Ed Bunn already downloaded; loading from file
# Player John Lynch already downloaded; loading from file
# Player Mike Middleton already downloaded; loading from file
# Player Lorenzo Neal already downloaded; loading from file
# Player Rudy Harris already downloaded; loading from file
# Player Derwin Gray already downloaded; loading from file
# Player Derrick Lassic already downloaded; loading from file
# Player Myron Baker already downloaded; loading from file
# Player Travis Hannah already downloaded; loading from file
# Player Jaime Fields already downloaded; loading from file
# Player Horace Copeland already downloaded; loading from file
# Player Kevin Henry already downloaded; loading from file
# Player Derek Brown already downloaded; loading from file
# Player Corwin Brown already downloaded; loading from file
# Player Russell Copeland already downloaded; loading from file
# Player Scott Sisson already downloaded; loading from file
# Player Fred Baxter already downloaded; loading from file
# Player Mark Brunell already downloaded; loading from file
# Player Adrian Murrell already downloaded; loading from file
# Player Sean LaChapelle already downloaded; loading from file
# Player Olanda Truitt already downloaded; loading from file
# Player Kevin Williams already downloaded; loading from file
# Player Kevin Williams already downloaded; loading from file
# Player Chuck Belin already downloaded; loading from file
# Player John Henry Mills already downloaded; loading from file
# Player Chris Gray already downloaded; loading from file
# Player Everett Lindsay already downloaded; loading from file
# Player Tyrone Hughes already downloaded; loading from file
# Player Rich Griffith already downloaded; loading from file
# Player Doug Evans already downloaded; loading from file
# Player Lawrence Hatch already downloaded; loading from file
# Player Richie Anderson already downloaded; loading from file
# Player Dave Hoffmann already downloaded; loading from file
# Player Greg Jeffries already downloaded; loading from file
# Player Deral Boykin already downloaded; loading from file
# Player Mitch Lyons already downloaded; loading from file
# Player Melvin Bonner already downloaded; loading from file
# Player Darryl Morrison already downloaded; loading from file
# Player Carlos Etheredge already downloaded; loading from file
# Player Darius Turner already downloaded; loading from file
# Player Frank Wycheck already downloaded; loading from file
# Player Eric Castle already downloaded; loading from file
# Player Barry Minter already downloaded; loading from file
# Player Clarence Williams already downloaded; loading from file
# Player Will White already downloaded; loading from file
# Player Keshon Johnson already downloaded; loading from file
# Player Ty Hallock already downloaded; loading from file
# Player Lance Gunn already downloaded; loading from file
# Player Darnell Walker already downloaded; loading from file
# Player Greg Biekert already downloaded; loading from file
# Player Lance Lewis already downloaded; loading from file
# Player Jeff Zgonina already downloaded; loading from file
# Player Danan Hughes already downloaded; loading from file
# Player Joey Mickey already downloaded; loading from file
# Player David Merritt already downloaded; loading from file
# Player Gino Torretta already downloaded; loading from file
# Player Othello Henderson already downloaded; loading from file
# Player Willie Harris already downloaded; loading from file
# Player Brock Marion already downloaded; loading from file
# Player Craig Hentrich already downloaded; loading from file
# Player Kevin Miniefield already downloaded; loading from file
# Player Doug Pelfrey already downloaded; loading from file
# Player Shannon Baker already downloaded; loading from file
# Player Jeff Buffaloe already downloaded; loading from file
# Player Brian Stablein already downloaded; loading from file
# Player Blaine Bishop already downloaded; loading from file
# Player Alex Van Pelt already downloaded; loading from file
# Player Elvis Grbac already downloaded; loading from file
# Player Darrick Branch already downloaded; loading from file
# Player Trent Green already downloaded; loading from file
# ***1994***
# Player Dan Wilkinson already downloaded; loading from file
# Player Marshall Faulk already downloaded; loading from file
# Player Heath Shuler already downloaded; loading from file
# Player Trev Alberts already downloaded; loading from file
# Player Trent Dilfer already downloaded; loading from file
# Player Sam Adams already downloaded; loading from file
# Player Antonio Langham already downloaded; loading from file
# Player Jamir Miller already downloaded; loading from file
# Player Aaron Glenn already downloaded; loading from file
# Player Wayne Gandy already downloaded; loading from file
# Player Aaron Taylor already downloaded; loading from file
# Player Charles Johnson already downloaded; loading from file
# Player Dewayne Washington already downloaded; loading from file
# Player Tim Bowens already downloaded; loading from file
# Player Johnnie Morton already downloaded; loading from file
# Player Rob Fredrickson already downloaded; loading from file
# Player Thomas Lewis already downloaded; loading from file
# Player Greg Hill already downloaded; loading from file
# Player Jeff Burris already downloaded; loading from file
# Player William Floyd already downloaded; loading from file
# Player Derrick Alexander already downloaded; loading from file
# Player Darnay Scott already downloaded; loading from file
# Player Eric Mahlum already downloaded; loading from file
# Player Isaac Bruce already downloaded; loading from file
# Player Errict Rhett already downloaded; loading from file
# Player Kevin Lee already downloaded; loading from file
# Player Chuck Levy already downloaded; loading from file
# Player David Palmer already downloaded; loading from file
# Player Ryan Yarborough already downloaded; loading from file
# Player Charlie Garner already downloaded; loading from file
# Player Isaac Davis already downloaded; loading from file
# Player Mario Bates already downloaded; loading from file
# Player Bert Emanuel already downloaded; loading from file
# Player Thomas Randolph already downloaded; loading from file
# Player Bucky Brooks already downloaded; loading from file
# Player Toby Wright already downloaded; loading from file
# Player Brentson Buckner already downloaded; loading from file
# Player Van Malone already downloaded; loading from file
# Player Donnell Bennett already downloaded; loading from file
# Player Jason Sehorn already downloaded; loading from file
# Player Jeremy Nunley already downloaded; loading from file
# Player Lonnie Johnson already downloaded; loading from file
# Player Tyronne Drakeford already downloaded; loading from file
# Player Vaughn Parker already downloaded; loading from file
# Player Jeff Cothran already downloaded; loading from file
# Player Tydus Winans already downloaded; loading from file
# Player Harold Bishop already downloaded; loading from file
# Player Andre Coleman already downloaded; loading from file
# Player Keith Lyle already downloaded; loading from file
# Player Lamar Smith already downloaded; loading from file
# Player Winfred Tubbs already downloaded; loading from file
# Player Calvin Jones already downloaded; loading from file
# Player Willie Clark already downloaded; loading from file
# Player James Bostic already downloaded; loading from file
# Player LeShon Johnson already downloaded; loading from file
# Player Doug Brien already downloaded; loading from file
# Player Steve Shine already downloaded; loading from file
# Player Cory Fleming already downloaded; loading from file
# Player Jason Gildon already downloaded; loading from file
# Player Bam Morris already downloaded; loading from file
# Player Lake Dawson already downloaded; loading from file
# Player Lou Benfatti already downloaded; loading from file
# Player Gary Downs already downloaded; loading from file
# Player Chris Penn already downloaded; loading from file
# Player Malcolm Floyd already downloaded; loading from file
# Player Eric Zomalt already downloaded; loading from file
# Player Corey Sawyer already downloaded; loading from file
# Player Kurt Haws already downloaded; loading from file
# Player Bradford Banta already downloaded; loading from file
# Player Chris Brantley already downloaded; loading from file
# Player Willie Jackson already downloaded; loading from file
# Player Perry Klein already downloaded; loading from file
# Player Raymont Harris already downloaded; loading from file
# Player Mitch Davis already downloaded; loading from file
# Player Mike Davis already downloaded; loading from file
# Player John Burke already downloaded; loading from file
# Player Vaughn Bryant already downloaded; loading from file
# Player Mike Wells already downloaded; loading from file
# Player Bracy Walker already downloaded; loading from file
# Player Sean Jackson already downloaded; loading from file
# Player Sean Crocker already downloaded; loading from file
# Player John Covington already downloaded; loading from file
# Player Shelly Hammonds already downloaded; loading from file
# Player Pat O'Neill already downloaded; loading from file
# Player Aaron Laing already downloaded; loading from file
# Player Harrison Houston already downloaded; loading from file
# Player Myron Bell already downloaded; loading from file
# Player Marvin Goodwin already downloaded; loading from file
# Player Dorsey Levens already downloaded; loading from file
# Player James Burton already downloaded; loading from file
# Player Rob Waldrop already downloaded; loading from file
# Player Roderick Lewis already downloaded; loading from file
# Player A.J. Ofodile already downloaded; loading from file
# Player Tony Vinson already downloaded; loading from file
# Player Lamont Warren already downloaded; loading from file
# Player Steve Hawkins already downloaded; loading from file
# Player Rickey Brady already downloaded; loading from file
# Player Max Lane already downloaded; loading from file
# Player Jay Kearney already downloaded; loading from file
# Player Lloyd Hill already downloaded; loading from file
# Player Robert Strait already downloaded; loading from file
# Player Terry Samuels already downloaded; loading from file
# Player Ruffin Hamilton already downloaded; loading from file
# Player Derrell Mitchell already downloaded; loading from file
# Player Jim Miller already downloaded; loading from file
# Player Jocelyn Borgella already downloaded; loading from file
# Player Anthony Daigle already downloaded; loading from file
# Player Lee Gissendaner already downloaded; loading from file
# Player Darren Studstill already downloaded; loading from file
# Player Kevin Knox already downloaded; loading from file
# Player Mitch Berger already downloaded; loading from file
# Player Barron Wortham already downloaded; loading from file
# Player Gus Frerotte already downloaded; loading from file
# Player Jay Walker already downloaded; loading from file
# Player Steve Matthews already downloaded; loading from file
# Player Jim Pyne already downloaded; loading from file
# Player Jamal Anderson already downloaded; loading from file
# Player Carlester Crumpler already downloaded; loading from file
# Player Frank Harvey already downloaded; loading from file
# Player Dennis Collier already downloaded; loading from file
# Player Mark Montgomery already downloaded; loading from file
# Player Glenn Foley already downloaded; loading from file
# Player Brice Abrams already downloaded; loading from file
# Player Keith Burns already downloaded; loading from file
# Player Butler By'not'e already downloaded; loading from file
# Player Rob Holmberg already downloaded; loading from file
# Player Tom Nalen already downloaded; loading from file
# ***1995***
# Player Ki-Jana Carter already downloaded; loading from file
# Player Tony Boselli already downloaded; loading from file
# Player Steve McNair already downloaded; loading from file
# Player Michael Westbrook already downloaded; loading from file
# Player Kerry Collins already downloaded; loading from file
# Player Kevin Carter already downloaded; loading from file
# Player Joey Galloway already downloaded; loading from file
# Player Kyle Brady already downloaded; loading from file
# Player J.J. Stokes already downloaded; loading from file
# Player Derrick Alexander already downloaded; loading from file
# Player Warren Sapp already downloaded; loading from file
# Player Mark Fields already downloaded; loading from file
# Player Ruben Brown already downloaded; loading from file
# Player Tyrone Wheatley already downloaded; loading from file
# Player Napoleon Kaufman already downloaded; loading from file
# Player James Stewart already downloaded; loading from file
# Player Luther Elliss already downloaded; loading from file
# Player Rashaan Salaam already downloaded; loading from file
# Player Ty Law already downloaded; loading from file
# Player Korey Stringer already downloaded; loading from file
# Player Devin Bush Sr. already downloaded; loading from file
# Player Mark Bruener already downloaded; loading from file
# Player Derrick Brooks already downloaded; loading from file
# Player Shawn King already downloaded; loading from file
# Player Cory Raymer already downloaded; loading from file
# Player Zach Wiegert already downloaded; loading from file
# Player Christian Fauria already downloaded; loading from file
# Player Ron Davis already downloaded; loading from file
# Player Melvin Johnson already downloaded; loading from file
# Player Ray Zellars already downloaded; loading from file
# Player Todd Collins already downloaded; loading from file
# Player Sherman Williams already downloaded; loading from file
# Player Frank Sanders already downloaded; loading from file
# Player Ken Dilger already downloaded; loading from file
# Player Bobby Taylor already downloaded; loading from file
# Player Terrell Fletcher already downloaded; loading from file
# Player Corey Fuller already downloaded; loading from file
# Player Todd Sauerbrun already downloaded; loading from file
# Player Ted Johnson already downloaded; loading from file
# Player Kendell Watkins already downloaded; loading from file
# Player Kordell Stewart already downloaded; loading from file
# Player Jimmy Oliver already downloaded; loading from file
# Player William Henderson already downloaded; loading from file
# Player Chris Sanders already downloaded; loading from file
# Player David Sloan already downloaded; loading from file
# Player Chris Hudson already downloaded; loading from file
# Player Brian Williams already downloaded; loading from file
# Player Curtis Martin already downloaded; loading from file
# Player Marlon Kerner already downloaded; loading from file
# Player Lorenzo Styles already downloaded; loading from file
# Player Chris Jones already downloaded; loading from file
# Player Zack Crockett already downloaded; loading from file
# Player Stoney Case already downloaded; loading from file
# Player Tamarick Vanover already downloaded; loading from file
# Player Steve McLaughlin already downloaded; loading from file
# Player Sean Harris already downloaded; loading from file
# Player Eric Zeier already downloaded; loading from file
# Player Rodney Young already downloaded; loading from file
# Player Rodney Thomas already downloaded; loading from file
# Player Antonio Freeman already downloaded; loading from file
# Player Brendan Stai already downloaded; loading from file
# Player Charlie Williams already downloaded; loading from file
# Player Torey Hunter already downloaded; loading from file
# Player Damien Covington already downloaded; loading from file
# Player Rob Johnson already downloaded; loading from file
# Player Michael Roan already downloaded; loading from file
# Player Sam Shade already downloaded; loading from file
# Player Larry Jones already downloaded; loading from file
# Player Aaron Hayden already downloaded; loading from file
# Player Tyrone Davis already downloaded; loading from file
# Player Dameian Jeffries already downloaded; loading from file
# Player Ken Irvin already downloaded; loading from file
# Player Eric Bjornson already downloaded; loading from file
# Player Chad May already downloaded; loading from file
# Player Justin Armour already downloaded; loading from file
# Player Lovell Pinkney already downloaded; loading from file
# Player Jack Jackson already downloaded; loading from file
# Player Mike Morton already downloaded; loading from file
# Player Dave Barr already downloaded; loading from file
# Player Pete Mitchell already downloaded; loading from file
# Player Ken Brown already downloaded; loading from file
# ...
# Player Al Afalava already downloaded; loading from file
# Player Coye Francies already downloaded; loading from file
# Player Aaron Brown already downloaded; loading from file
# Player Brandon Gibson already downloaded; loading from file
# Player James Davis already downloaded; loading from file
# Player Jake Ingram already downloaded; loading from file
# Player Stryker Sulak already downloaded; loading from file
# Player Curtis Painter already downloaded; loading from file
# Player Brandon Myers already downloaded; loading from file
# Player Jason McCourty already downloaded; loading from file
# Player Will Davis already downloaded; loading from file
# Player Ra'Shon Harris already downloaded; loading from file
# Player Myron Pryor already downloaded; loading from file
# Player John Phillips already downloaded; loading from file
# Player Vance Walker already downloaded; loading from file
# Player Chris Ogbonnaya already downloaded; loading from file
# Player Captain Munnerlyn already downloaded; loading from file
# Player E.J. Biggers already downloaded; loading from file
# Player Brad Jones already downloaded; loading from file
# Player Curtis Taylor already downloaded; loading from file
# Player Ellis Lankster already downloaded; loading from file
# Player Eddie Williams already downloaded; loading from file
# Player Pat McAfee already downloaded; loading from file
# Player Troy Nolan already downloaded; loading from file
# Player Demetrius Byrd already downloaded; loading from file
# Player A.Q. Shipley already downloaded; loading from file
# Player Lydon Murtha already downloaded; loading from file
# Player Manuel Johnson already downloaded; loading from file
# Player Moise Fokou already downloaded; loading from file
# Player Jamarca Sanford already downloaded; loading from file
# Player Julian Edelman already downloaded; loading from file
# Player Sammie Stroughter already downloaded; loading from file
# Player Zack Follett already downloaded; loading from file
# Player Jaimie Thomas already downloaded; loading from file
# Player Jake O'Connell already downloaded; loading from file
# Player Stoney Woodson already downloaded; loading from file
# Player Ryan Durand already downloaded; loading from file
# Player LaRod Stephens-Howling already downloaded; loading from file
# Player David Johnson already downloaded; loading from file
# Player Marko Mitchell already downloaded; loading from file
# Player Ricky Jean-Francois already downloaded; loading from file
# Player Courtney Greene already downloaded; loading from file
# Player Lance Louis already downloaded; loading from file
# Player Nick Reed already downloaded; loading from file
# Player Cameron Morrah already downloaded; loading from file
# Player Clinton McDonald already downloaded; loading from file
# Player Derek Kinder already downloaded; loading from file
# Player Freddie Brown already downloaded; loading from file
# Player Tiquan Underwood already downloaded; loading from file
# Player Dan Gronkowski already downloaded; loading from file
# ***2010***
# Player Sam Bradford already downloaded; loading from file
# Player Ndamukong Suh already downloaded; loading from file
# Player Gerald McCoy already downloaded; loading from file
# Player Trent Williams already downloaded; loading from file
# Player Eric Berry already downloaded; loading from file
# Player Russell Okung already downloaded; loading from file
# Player Joe Haden already downloaded; loading from file
# Player Rolando McClain already downloaded; loading from file
# Player C.J. Spiller already downloaded; loading from file
# Player Tyson Alualu already downloaded; loading from file
# Player Anthony Davis already downloaded; loading from file
# Player Ryan Mathews already downloaded; loading from file
# Player Brandon Graham already downloaded; loading from file
# Player Earl Thomas already downloaded; loading from file
# Player Jason Pierre-Paul already downloaded; loading from file
# Player Derrick Morgan already downloaded; loading from file
# Player Mike Iupati already downloaded; loading from file
# Player Maurkice Pouncey already downloaded; loading from file
# Player Sean Weatherspoon already downloaded; loading from file
# Player Kareem Jackson already downloaded; loading from file
# Player Jermaine Gresham already downloaded; loading from file
# Player Demaryius Thomas already downloaded; loading from file
# Player Dez Bryant already downloaded; loading from file
# Player Tim Tebow already downloaded; loading from file
# Player Dan Williams already downloaded; loading from file
# Player Devin McCourty already downloaded; loading from file
# Player Jared Odrick already downloaded; loading from file
# Player Kyle Wilson already downloaded; loading from file
# Player Jahvid Best already downloaded; loading from file
# Player Jerry Hughes already downloaded; loading from file
# Player Patrick Robinson already downloaded; loading from file
# Player Rodger Saffold already downloaded; loading from file
# Player Chris Cook already downloaded; loading from file
# Player Brian Price already downloaded; loading from file
# Player Dexter McCluster already downloaded; loading from file
# Player Nate Allen already downloaded; loading from file
# Player T.J. Ward already downloaded; loading from file
# Player Arrelious Benn already downloaded; loading from file
# Player Koa Misi already downloaded; loading from file
# Player Rob Gronkowski already downloaded; loading from file
# Player Lamarr Houston already downloaded; loading from file
# Player Zane Beadles already downloaded; loading from file
# Player Linval Joseph already downloaded; loading from file
# Player Daryl Washington already downloaded; loading from file
# Player Jimmy Clausen already downloaded; loading from file
# Player Taylor Mays already downloaded; loading from file
# Player Javier Arenas already downloaded; loading from file
# Player Toby Gerhart already downloaded; loading from file
# Player Jason Worilds already downloaded; loading from file
# Player Jermaine Cunningham already downloaded; loading from file
# Player Carlos Dunlap already downloaded; loading from file
# Player Sean Lee already downloaded; loading from file
# Player Mike Neal already downloaded; loading from file
# Player Terrence Cody already downloaded; loading from file
# Player Ben Tate already downloaded; loading from file
# Player Montario Hardesty already downloaded; loading from file
# Player Golden Tate already downloaded; loading from file
# Player Brandon Spikes already downloaded; loading from file
# Player Pat Angerer already downloaded; loading from file
# Player Charles Brown already downloaded; loading from file
# Player Jerome Murphy already downloaded; loading from file
# Player Amari Spievey already downloaded; loading from file
# Player Myron Lewis already downloaded; loading from file
# Player Ed Dickson already downloaded; loading from file
# Player Morgan Burnett already downloaded; loading from file
# Player Alex Carrington already downloaded; loading from file
# Player D'Anthony Smith already downloaded; loading from file
# Player Major Wright already downloaded; loading from file
# Player Chad Jones already downloaded; loading from file
# Player Damian Williams already downloaded; loading from file
# Player Brandon LaFell already downloaded; loading from file
# Player J.D. Walton already downloaded; loading from file
# Player Earl Mitchell already downloaded; loading from file
# Player Emmanuel Sanders already downloaded; loading from file
# Player Corey Peters already downloaded; loading from file
# Player Jordan Shipley already downloaded; loading from file
# Player Colt McCoy already downloaded; loading from file
# Player Daniel Te'o-Nesheim already downloaded; loading from file
# Player Eric Decker already downloaded; loading from file
# Player Taylor Price already downloaded; loading from file
# Player NaVorro Bowman already downloaded; loading from file
# Player Shawn Lauvao already downloaded; loading from file
# Player Tony Moeaki already downloaded; loading from file
# Player Jimmy Graham already downloaded; loading from file
# Player Brandon Ghee already downloaded; loading from file
# Player Rennie Curran already downloaded; loading from file
# Player Mardy Gilyard already downloaded; loading from file
# Player Everson Griffen already downloaded; loading from file
# Player Mike Williams already downloaded; loading from file
# Player Darryl Sharpton already downloaded; loading from file
# Player Perry Riley already downloaded; loading from file
# Player Alterraun Verner already downloaded; loading from file
# Player Trevard Lindley already downloaded; loading from file
# Player Bruce Campbell already downloaded; loading from file
# Player Jacoby Ford already downloaded; loading from file
# Player Corey Wootton already downloaded; loading from file
# Player Darrell Stuckey already downloaded; loading from file
# Player Walter Thurmond already downloaded; loading from file
# Player Joe McKnight already downloaded; loading from file
# Player Aaron Hernandez already downloaded; loading from file
# Player Dennis Pitta already downloaded; loading from file
# Player Phillip Dillard already downloaded; loading from file
# Player Thaddeus Gibson already downloaded; loading from file
# Player Joe Hawley already downloaded; loading from file
# Player Garrett Graham already downloaded; loading from file
# Player Geno Atkins already downloaded; loading from file
# Player Keenan Clayton already downloaded; loading from file
# Player Mike Kafka already downloaded; loading from file
# Player Al Woods already downloaded; loading from file
# Player Eric Norwood already downloaded; loading from file
# Player E.J. Wilson already downloaded; loading from file
# Player Jason Fox already downloaded; loading from file
# Player Jacques McClendon already downloaded; loading from file
# Player O'Brien Schofield already downloaded; loading from file
# Player Roddrick Muckelroy already downloaded; loading from file
# Player Michael Hoomanawanui already downloaded; loading from file
# Player Kam Chancellor already downloaded; loading from file
# Player Ricky Sapp already downloaded; loading from file
# Player Dominique Franks already downloaded; loading from file
# Player Kendrick Lewis already downloaded; loading from file
# Player Perrish Cox already downloaded; loading from file
# Player Walter McFadden already downloaded; loading from file
# Player John Conner already downloaded; loading from file
# Player Ed Wang already downloaded; loading from file
# Player Joshua Moore already downloaded; loading from file
# Player Cameron Sheffield already downloaded; loading from file
# Player Sherrick McManis already downloaded; loading from file
# Player Nolan Carroll already downloaded; loading from file
# Player Cam Thomas already downloaded; loading from file
# Player Mitch Petrus already downloaded; loading from file
# Player Zoltan Mesko already downloaded; loading from file
# Player Andrew Quarless already downloaded; loading from file
# Player David Reed already downloaded; loading from file
# Player Arthur Jones already downloaded; loading from file
# Player Riley Cooper already downloaded; loading from file
# Player Larry Asante already downloaded; loading from file
# Player Brody Eldridge already downloaded; loading from file
# Player Reshad Jones already downloaded; loading from file
# Player Crezdon Butler already downloaded; loading from file
# Player Stevenson Sylvester already downloaded; loading from file
# Player Nate Triplett already downloaded; loading from file
# Player Marshall Newhouse already downloaded; loading from file
# Player Fendi Onobun already downloaded; loading from file
# Player Brent Bowden already downloaded; loading from file
# Player Anthony Dixon already downloaded; loading from file
# Player Dennis Morris already downloaded; loading from file
# Player Greg Hardy already downloaded; loading from file
# Player Rusty Smith already downloaded; loading from file
# Player Carlton Mitchell already downloaded; loading from file
# Player Nate Byham already downloaded; loading from file
# Player Eric Olsen already downloaded; loading from file
# Player Anthony McCoy already downloaded; loading from file
# Player Clifton Geathers already downloaded; loading from file
# Player Jonathan Dwyer already downloaded; loading from file
# Player Travis Goethel already downloaded; loading from file
# Player Dezmon Briscoe already downloaded; loading from file
# Player James Starks already downloaded; loading from file
# Player Antonio Brown already downloaded; loading from file
# Player Jamar Wall already downloaded; loading from file
# Player Trindon Holliday already downloaded; loading from file
# Player David Gettis already downloaded; loading from file
# Player Joe Webb already downloaded; loading from file
# Player Charles Scott already downloaded; loading from file
# Player Jorrick Calvin already downloaded; loading from file
# Player Jordan Pugh already downloaded; loading from file
# Player Tony Pike already downloaded; loading from file
# Player Ted Larsen already downloaded; loading from file
# Player Kyle Williams already downloaded; loading from file
# Player Thomas Welch already downloaded; loading from file
# Player Levi Brown already downloaded; loading from file
# Player Cody Grimm already downloaded; loading from file
# Player Marquis Johnson already downloaded; loading from file
# Player Willie Young already downloaded; loading from file
# Player Mickey Shuler already downloaded; loading from file
# Player Jeremy Ware already downloaded; loading from file
# Player Kyle Calloway already downloaded; loading from file
# Player Dekoda Watson already downloaded; loading from file
# Player Terrence Austin already downloaded; loading from file
# Player Jamar Chaney already downloaded; loading from file
# Player Matt Dodge already downloaded; loading from file
# Player Syd'Quan Thompson already downloaded; loading from file
# Player George Selvie already downloaded; loading from file
# Player Dorin Dickerson already downloaded; loading from file
# Player C.J. Wilson already downloaded; loading from file
# Player Selvish Capers already downloaded; loading from file
# Player Jammie Kirlew already downloaded; loading from file
# Player Jim Dray already downloaded; loading from file
# Player Dedrick Epps already downloaded; loading from file
# Player Dexter Davis already downloaded; loading from file
# Player Ricardo Mathews already downloaded; loading from file
# Player Kavell Conner already downloaded; loading from file
# Player Jeff Owens already downloaded; loading from file
# Player Kurt Coleman already downloaded; loading from file
# Player Ray Fisher already downloaded; loading from file
# Player Brandon Deaderick already downloaded; loading from file
# Player Kade Weston already downloaded; loading from file
# Player Robert McClain already downloaded; loading from file
# Player Stevie Brown already downloaded; loading from file
# Player Austin Spitler already downloaded; loading from file
# Player Erik Lorig already downloaded; loading from file
# Player Josh Hull already downloaded; loading from file
#       conf       cname                                  cname_link  cseasons  \
# 0  Big Ten    Illinois             /cfb/schools/illinois/1989.html       3.0
# 1      Ind  Penn State           /cfb/schools/penn-state/1989.html       4.0
# 2      NaN         NaN                                         NaN       NaN
# 3      SEC     Alabama              /cfb/schools/alabama/1989.html       2.0
# 4   Pac-10         USC  /cfb/schools/southern-california/1989.html       1.0
#
#    cgames          player  year  \
# 0    34.0     Jeff George  1990
# 1    44.0    Blair Thomas  1990
# 2     NaN  Cortez Kennedy  1990
# 3    22.0   Keith McCants  1990
# 4    12.0     Junior Seau  1990
#
#                                                clink                    plink
# 0  http://www.sports-reference.com/cfb/players/je...  /players/G/GeorJe00.htm
# 1  http://www.sports-reference.com/cfb/players/bl...  /players/T/ThomBl00.htm
# 2                                                     /players/K/KennCo00.htm
# 3  http://www.sports-reference.com/cfb/players/ke...  /players/M/McCaKe21.htm
# 4  http://www.sports-reference.com/cfb/players/ju...  /players/S/SeauJu00.htm

# %%
collegedf.to_csv('df/collegedf3.csv')

# %%
collegedf.sample(34)
# Out:
#          conf              cname                                cname_link  \
# 190    Big 12             Kansas             /cfb/schools/kansas/2009.html
# 207       NaN                NaN                                       NaN
# 83   Big West  Northern Illinois  /cfb/schools/northern-illinois/1993.html
# 168       NaN                NaN                                       NaN
# 240       NaN                NaN                                       NaN
# 22    Big Ten           Michigan           /cfb/schools/michigan/1994.html
# 174       ACC      Florida State      /cfb/schools/florida-state/2007.html
# 173    Pac-10               UCLA               /cfb/schools/ucla/2004.html
# 136       NaN                NaN                                       NaN
# 141       NaN                NaN                                       NaN
# 130       ACC      Florida State      /cfb/schools/florida-state/2003.html
# 229       NaN                NaN                                       NaN
# 124       NaN                NaN                                       NaN
# 232    Pac-10       Oregon State       /cfb/schools/oregon-state/1989.html
# 132       SEC  Mississippi State  /cfb/schools/mississippi-state/1999.html
# 47   Big East         Miami (FL)           /cfb/schools/miami-fl/1992.html
# 44     Big 12          Texas A&M           /cfb/schools/texas-am/2002.html
# 68     Pac-10         Washington         /cfb/schools/washington/1994.html
# 210       SEC            Alabama            /cfb/schools/alabama/2009.html
# 237   Big Ten           Illinois           /cfb/schools/illinois/1990.html
# 152       NaN                NaN                                       NaN
# 121   Big Ten       Northwestern       /cfb/schools/northwestern/2009.html
# 76        NaN                NaN                                       NaN
# 31    Big Ten            Indiana            /cfb/schools/indiana/1996.html
# 219    Pac-10      Arizona State      /cfb/schools/arizona-state/2007.html
# 205       NaN                NaN                                       NaN
# 229       NaN                NaN                                       NaN
# 89        ACC           Virginia           /cfb/schools/virginia/1986.html
# 199       NaN                NaN                                       NaN
# 117       NaN                NaN                                       NaN
# 279       NaN                NaN                                       NaN
# 92     Pac-10           Stanford           /cfb/schools/stanford/2006.html
# 153       SWC              Texas              /cfb/schools/texas/1989.html
# 98        NaN                NaN                                       NaN
#
#      cseasons  cgames            player  year  \
# 190       3.0    37.0    Dezmon Briscoe  2010
# 207       NaN     NaN      Frank Walker  2003
# 83        2.0    22.0    LeShon Johnson  1994
# 168       NaN     NaN      Dwayne White  1990
# 240       NaN     NaN        Sean Morey  1999
# 22        2.0    24.0            Ty Law  1995
# 174       3.0    36.0        Geno Hayes  2008
# 173       4.0    46.0       Ben Emanuel  2005
# 136       NaN     NaN          Joe Horn  1996
# 141       NaN     NaN     Terry Charles  2002
# 130       1.0    13.0    Chauncey Davis  2005
# 229       NaN     NaN         Jeff Grau  2002
# 124       NaN     NaN          Ed Ellis  1997
# 232       5.0    36.0         Phil Ross  1990
# 132       2.0    23.0       Robert Bean  2000
# 47        3.0    32.0    Kevin Williams  1993
# 44        4.0    35.0    Bethel Johnson  2003
# 68        1.0    10.0          Bob Sapp  1997
# 210       4.0    49.0   Marquis Johnson  2010
# 237       4.0    46.0   Howard Griffith  1991
# 152       NaN     NaN      Sean Woodson  1997
# 121       4.0    30.0        Mike Kafka  2010
# 76        NaN     NaN   Derrick Frazier  1993
# 31        1.0    10.0      Nathan Davis  1997
# 219       4.0    46.0      Josh Barrett  2008
# 205       NaN     NaN        James Reed  2001
# 229       NaN     NaN     Gregory Spann  1996
# 89        2.0    22.0      Chris Warren  1990
# 199       NaN     NaN    Richard Hogans  1997
# 117       NaN     NaN     Vance Hammond  1991
# 279       NaN     NaN   Tony De Lorenzo  1991
# 92        4.0    35.0     Trent Edwards  2007
# 153       4.0    38.0        Tony Jones  1990
# 98        NaN     NaN  Alai Kalaniuvalu  1994
#
#                                                  clink  \
# 190  http://www.sports-reference.com/cfb/players/de...
# 207
# 83   http://www.sports-reference.com/cfb/players/le...
# 168
# 240
# 22   http://www.sports-reference.com/cfb/players/ty...
# 174  http://www.sports-reference.com/cfb/players/ge...
# 173  http://www.sports-reference.com/cfb/players/be...
# 136
# 141
# 130  http://www.sports-reference.com/cfb/players/ch...
# 229
# 124
# 232  http://www.sports-reference.com/cfb/players/ph...
# 132  http://www.sports-reference.com/cfb/players/ro...
# 47   http://www.sports-reference.com/cfb/players/ke...
# 44   http://www.sports-reference.com/cfb/players/be...
# 68   http://www.sports-reference.com/cfb/players/bo...
# 210  http://www.sports-reference.com/cfb/players/ma...
# 237  http://www.sports-reference.com/cfb/players/ho...
# 152
# 121  http://www.sports-reference.com/cfb/players/mi...
# 76
# 31   http://www.sports-reference.com/cfb/players/na...
# 219  http://www.sports-reference.com/cfb/players/jo...
# 205
# 229
# 89   http://www.sports-reference.com/cfb/players/ch...
# 199
# 117
# 279
# 92   http://www.sports-reference.com/cfb/players/tr...
# 153  http://www.sports-reference.com/cfb/players/to...
# 98
#
#                        plink
# 190                      NaN
# 207                      NaN
# 83   /players/J/JohnLe01.htm
# 168  /players/W/WhitDw20.htm
# 240  /players/M/MoreSe00.htm
# 22   /players/L/LawxTy00.htm
# 174                      NaN
# 173                      NaN
# 136  /players/H/HornJo00.htm
# 141                      NaN
# 130                      NaN
# 229                      NaN
# 124  /players/E/ElliEd20.htm
# 232
# 132                      NaN
# 47   /players/W/WillKe00.htm
# 44                       NaN
# 68   /players/S/SappBo20.htm
# 210                      NaN
# 237  /players/G/GrifHo00.htm
# 152
# 121                      NaN
# 76   /players/F/FrazDe20.htm
# 31   /players/D/DaviNa20.htm
# 219                      NaN
# 205                      NaN
# 229
# 89   /players/W/WarrCh00.htm
# 199
# 117
# 279
# 92                       NaN
# 153  /players/J/JoneTo00.htm
# 98

# %%
collegedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5493 entries, 0 to 253
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   conf        3361 non-null   object
#  1   cname       3361 non-null   object
#  2   cname_link  3361 non-null   object
#  3   cseasons    3361 non-null   float64
#  4   cgames      3361 non-null   float64
#  5   player      5493 non-null   object
#  6   year        5493 non-null   int64
#  7   clink       5493 non-null   object
#  8   plink       2691 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 429.1+ KB

# %%
collegedf["year2"] = collegedf.year.astype(str)
players['year2'] = players.year

# %%
new_df = pd.merge(players, collegedf, how ='left', 
                  on = ['player', 'year2'])

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5619 entries, 0 to 5618
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   draft_round       5619 non-null   object
#  1   draft_pick        5619 non-null   object
#  2   team              5619 non-null   object
#  3   player            5619 non-null   object
#  4   pos_x             5619 non-null   object
#  5   age               5619 non-null   object
#  6   year_max          5619 non-null   object
#  7   g                 5619 non-null   object
#  8   college_id        5619 non-null   object
#  9   player_link       2787 non-null   object
#  10  college_link      5619 non-null   object
#  11  year_x            5619 non-null   object
#  12  playernametolink  5619 non-null   object
#  13  school_name       4493 non-null   object
#  14  pos_y             4493 non-null   object
#  15  height            4493 non-null   object
#  16  weight            4493 non-null   object
#  17  wonderlic         2143 non-null   object
#  18  forty_yd          4493 non-null   object
#  19  bench_reps        4493 non-null   object
#  20  vertical          4493 non-null   object
#  21  broad_jump        4493 non-null   object
#  22  shuttle           4493 non-null   object
#  23  cone              4493 non-null   object
#  24  height_in         5619 non-null   int64
#  25  DraftYr           5619 non-null   int64
#  26  player_link_x     2832 non-null   object
#  27  player_link_y     2350 non-null   object
#  28  year2             5619 non-null   object
#  29  conf              3454 non-null   object
#  30  cname             3454 non-null   object
#  31  cname_link        3454 non-null   object
#  32  cseasons          3454 non-null   float64
#  33  cgames            3454 non-null   float64
#  34  year_y            5619 non-null   int64
#  35  clink             5619 non-null   object
#  36  plink             2787 non-null   object
# dtypes: float64(2), int64(3), object(32)
# memory usage: 1.6+ MB

# %%
new_df.sample(40)
# Out:
#      draft_round draft_pick team            player pos_x age year_max    g  \
# 5165           2         56  IND        Fili Moala    DT  24     2014   64
# 2944           5        158  NOR   Austin Wheatley    TE  22     2000    4
# 1320           1          9  CLE   Antonio Langham    DB  22     2000  102
# 4260           5        174  SFO  Rasheed Marshall    WR  24     2005   12
# 4808           6        204  TEN        Jacob Ford    DE  24     2010   43
# 3195           5        153  NOR         Onomo Ojo    WR
# 5111           1          2  STL       Jason Smith     T  23     2012   45
# 3785           7        235  DEN   Ahmaad Galloway    RB
# 1212           5        131  HOU  John Henry Mills    LB  23     1999  100
# 2190           5        141  CHI         Van Hiles    DB  21     1997   16
# 3782           7        232  WAS     Gibran Hamdan    QB  22     2003    1
# 3439           5        152  NYG      Nick Greisen    LB  23     2008   98
# 4491           5        144  STL    Marques Hagans    WR  23     2008    6
# 2043           7        247  NWE       J.R. Conrad     G  22     1997   12
# 728            1         19  ATL        Tony Smith    RB  22     1994   33
# 4352           1          5  GNB         A.J. Hawk    LB  22     2016  159
# 1593           2         60  PIT   Kordell Stewart    QB  22     2005  125
# 5046           6        188  PIT       Mike Humpal    LB  23
# 203            7        188  MIN      John Levelis    LB
# 2033           7        237  BUF   Dan Brandenburg    LB  23     1999   42
# 4120           2         41  TEN      Michael Roos     T  22     2014  148
# 634           10        270  WAS        Cris Shale     P
# 4390           2         43  NOR      Roman Harper    DB  23     2016  156
# 1200           5        126  DEN    Kevin Williams    RB  23     1993    3
# 815            4        104  ATL     Frankie Smith    DB  23     2000  103
# 2536           1          2  PHI    Donovan McNabb    QB  22     2011  167
# 5398           2         34  MIN        Chris Cook    DB  23     2014   40
# 477            5        123  SDG       Duane Young    TE  23     1998   73
# 2213           6        164  NYJ        Tim Scharf    LB
# 3787           7        237  NYJ   Dave Yovanovits     G  22     2005    6
# 4044           7        233  NWE  Christian Morton    DB  23     2006   14
# 3023           7        234  TAM      Joe Hamilton    QB  23     2000    1
# 2134           3         85  OAK          Tim Kohn     T
# 2293           7        238  BAL     Leland Taylor    DT  24     1997    1
# 5062           6        204  MIA      Lex Hilliard    RB  24     2012   62
# 4999           5        141  CAR     Gary Barnidge    TE  22     2016  124
# 712            1         15  NYJ   Johnny Mitchell    TE  21     1996   57
# 3709           5        159  ATL       Jon Olinger    WR
# 37             2         31  PHO  Anthony Thompson    RB  23     1992   37
# 4272           6        186  NYG        Eric Moore    DE  24     2011   35
#
#             college_id              player_link  ...            player_link_y  \
# 5165               USC                      NaN  ...  /players/M/MoalFi99.htm
# 2944              Iowa                      NaN  ...  /players/W/WheaAu20.htm
# 1320           Alabama  /players/L/LangAn20.htm  ...                      NaN
# 4260     West Virginia                      NaN  ...  /players/M/MarsRa00.htm
# 4808  Central Arkansas                      NaN  ...  /players/F/FordJa99.htm
# 3195  California-Davis                      NaN  ...                      NaN
# 5111            Baylor                      NaN  ...  /players/S/SmitJa22.htm
# 3785           Alabama                      NaN  ...
# 1212       Wake Forest  /players/M/MillJo00.htm  ...                      NaN
# 2190          Kentucky  /players/H/HileVa20.htm  ...                      NaN
# 3782           Indiana                      NaN  ...                      NaN
# 3439         Wisconsin                      NaN  ...                      NaN
# 4491          Virginia                      NaN  ...  /players/H/HagaMa00.htm
# 2043          Oklahoma  /players/C/ConrJ.20.htm  ...                      NaN
# 728      Southern Miss  /players/S/SmitTo00.htm  ...                      NaN
# 4352          Ohio St.                      NaN  ...  /players/H/HawkA.20.htm
# 1593          Colorado  /players/S/StewKo00.htm  ...                      NaN
# 5046              Iowa                      NaN  ...  /players/H/HumpMi99.htm
# 203          C.W. Post                           ...                      NaN
# 2033       Indiana St.  /players/B/BranDa20.htm  ...                      NaN
# 4120  East. Washington                      NaN  ...  /players/R/RoosMi20.htm
# 634      Bowling Green                           ...                      NaN
# 4390           Alabama                      NaN  ...  /players/H/HarpRo21.htm
# 1200              UCLA  /players/W/WillKe23.htm  ...                      NaN
# 815             Baylor  /players/S/SmitFr20.htm  ...                      NaN
# 2536          Syracuse  /players/M/McNaDo00.htm  ...                      NaN
# 5398          Virginia                      NaN  ...  /players/C/CookCh99.htm
# 477       Michigan St.  /players/Y/YounDu00.htm  ...                      NaN
# 2213      Northwestern                           ...                      NaN
# 3787            Temple                      NaN  ...                      NaN
# 4044          Illinois                      NaN  ...                      NaN
# 3023      Georgia Tech                      NaN  ...  /players/H/HamiJo20.htm
# 2134          Iowa St.                           ...                      NaN
# 2293        Louisville  /players/T/TaylLe20.htm  ...                      NaN
# 5062           Montana                      NaN  ...  /players/H/HillLe00.htm
# 4999        Louisville                      NaN  ...  /players/B/BarnGa01.htm
# 712           Nebraska  /players/M/MitcJo00.htm  ...                      NaN
# 3709        Cincinnati                      NaN  ...                      NaN
# 37             Indiana  /players/T/ThomAn00.htm  ...                      NaN
# 4272       Florida St.                      NaN  ...  /players/M/MoorEr21.htm
#
#      year2      conf                 cname  \
# 5165  2009    Pac-10                   USC
# 2944  2000   Big Ten                  Iowa
# 1320  1994       SEC               Alabama
# 4260  2005  Big East         West Virginia
# 4808  2007       NaN                   NaN
# 3195  2001       NaN                   NaN
# 5111  2009    Big 12                Baylor
# 3785  2003       SEC               Alabama
# 1212  1993       ACC           Wake Forest
# 2190  1997       SEC              Kentucky
# 3782  2003   Big Ten               Indiana
# 3439  2002   Big Ten             Wisconsin
# 4491  2006       ACC              Virginia
# 2043  1996       NaN                   NaN
# 728   1992       Ind  Southern Mississippi
# 4352  2006   Big Ten            Ohio State
# 1593  1995     Big 8              Colorado
# 5046  2008   Big Ten                  Iowa
# 203   1990       NaN                   NaN
# 2033  1996       NaN                   NaN
# 4120  2005       NaN                   NaN
# 634   1991       MAC   Bowling Green State
# 4390  2006       SEC               Alabama
# 1200  1993  Big East            Miami (FL)
# 815   1992       NaN                   NaN
# 2536  1999  Big East              Syracuse
# 5398  2010       ACC              Virginia
# 477   1991   Big Ten        Michigan State
# 2213  1997   Big Ten          Northwestern
# 3787  2003       NaN                   NaN
# 4044  2004   Big Ten              Illinois
# 3023  2000       ACC          Georgia Tech
# 2134  1997       NaN                   NaN
# 2293  1997       NaN                   NaN
# 5062  2008       NaN                   NaN
# 4999  2008  Big East            Louisville
# 712   1992     Big 8              Nebraska
# 3709  2003      CUSA            Cincinnati
# 37    1990   Big Ten               Indiana
# 4272  2005       ACC         Florida State
#
#                                        cname_link cseasons cgames year_y  \
# 5165   /cfb/schools/southern-california/2008.html      4.0   51.0   2009
# 2944                  /cfb/schools/iowa/1999.html      3.0   33.0   2000
# 1320               /cfb/schools/alabama/1993.html      4.0   44.0   1994
# 4260         /cfb/schools/west-virginia/2004.html      4.0   39.0   2005
# 4808                                          NaN      NaN    NaN   2007
# 3195                                          NaN      NaN    NaN   2001
# 5111                /cfb/schools/baylor/2007.html      3.0   30.0   2009
# 3785               /cfb/schools/alabama/2002.html      4.0   38.0   2003
# 1212           /cfb/schools/wake-forest/1992.html      5.0   54.0   1993
# 2190              /cfb/schools/kentucky/1996.html      3.0   29.0   1997
# 3782               /cfb/schools/indiana/2002.html      3.0   30.0   2003
# 3439             /cfb/schools/wisconsin/2001.html      2.0   25.0   2002
# 4491              /cfb/schools/virginia/2005.html      4.0   51.0   2006
# 2043                                          NaN      NaN    NaN   1996
# 728   /cfb/schools/southern-mississippi/1991.html      3.0   33.0   1992
# 4352            /cfb/schools/ohio-state/2005.html      4.0   51.0   2006
# 1593              /cfb/schools/colorado/1994.html      4.0   33.0   1995
# 5046                  /cfb/schools/iowa/2007.html      3.0   35.0   2008
# 203                                           NaN      NaN    NaN   1990
# 2033                                          NaN      NaN    NaN   1996
# 4120                                          NaN      NaN    NaN   2005
# 634    /cfb/schools/bowling-green-state/1990.html      3.0   32.0   1991
# 4390               /cfb/schools/alabama/2005.html      3.0   37.0   2006
# 1200              /cfb/schools/miami-fl/1992.html      3.0   32.0   1993
# 815                                           NaN      NaN    NaN   1992
# 2536              /cfb/schools/syracuse/1998.html      4.0   45.0   1999
# 5398              /cfb/schools/virginia/2009.html      4.0   39.0   2010
# 477         /cfb/schools/michigan-state/1990.html      4.0   48.0   1991
# 2213          /cfb/schools/northwestern/1996.html      1.0   12.0   1997
# 3787                                          NaN      NaN    NaN   2003
# 4044              /cfb/schools/illinois/2003.html      4.0   44.0   2004
# 3023          /cfb/schools/georgia-tech/1999.html      4.0   43.0   2000
# 2134                                          NaN      NaN    NaN   1997
# 2293                                          NaN      NaN    NaN   1997
# 5062                                          NaN      NaN    NaN   2008
# 4999            /cfb/schools/louisville/2007.html      4.0   47.0   2008
# 712               /cfb/schools/nebraska/1991.html      2.0   21.0   1992
# 3709            /cfb/schools/cincinnati/2002.html      4.0   34.0   2003
# 37                 /cfb/schools/indiana/1989.html      4.0   47.0   1990
# 4272         /cfb/schools/florida-state/2004.html      2.0   22.0   2005
#
#                                                   clink  \
# 5165  http://www.sports-reference.com/cfb/players/fi...
# 2944  http://www.sports-reference.com/cfb/players/au...
# 1320  http://www.sports-reference.com/cfb/players/an...
# 4260  http://www.sports-reference.com/cfb/players/ra...
# 4808
# 3195
# 5111  http://www.sports-reference.com/cfb/players/ja...
# 3785  http://www.sports-reference.com/cfb/players/ah...
# 1212  http://www.sports-reference.com/cfb/players/jo...
# 2190  http://www.sports-reference.com/cfb/players/va...
# 3782  http://www.sports-reference.com/cfb/players/gi...
# 3439  http://www.sports-reference.com/cfb/players/ni...
# 4491  http://www.sports-reference.com/cfb/players/ma...
# 2043
# 728   http://www.sports-reference.com/cfb/players/to...
# 4352  http://www.sports-reference.com/cfb/players/aj...
# 1593  http://www.sports-reference.com/cfb/players/ko...
# 5046  http://www.sports-reference.com/cfb/players/mi...
# 203
# 2033
# 4120
# 634   http://www.sports-reference.com/cfb/players/cr...
# 4390  http://www.sports-reference.com/cfb/players/ro...
# 1200  http://www.sports-reference.com/cfb/players/ke...
# 815
# 2536  http://www.sports-reference.com/cfb/players/do...
# 5398  http://www.sports-reference.com/cfb/players/ch...
# 477   http://www.sports-reference.com/cfb/players/du...
# 2213  http://www.sports-reference.com/cfb/players/ti...
# 3787
# 4044  http://www.sports-reference.com/cfb/players/ch...
# 3023  http://www.sports-reference.com/cfb/players/jo...
# 2134
# 2293
# 5062
# 4999  http://www.sports-reference.com/cfb/players/ga...
# 712   http://www.sports-reference.com/cfb/players/jo...
# 3709  http://www.sports-reference.com/cfb/players/jo...
# 37    http://www.sports-reference.com/cfb/players/an...
# 4272  http://www.sports-reference.com/cfb/players/er...
#
#                         plink
# 5165                      NaN
# 2944                      NaN
# 1320  /players/L/LangAn20.htm
# 4260                      NaN
# 4808                      NaN
# 3195                      NaN
# 5111                      NaN
# 3785                      NaN
# 1212  /players/M/MillJo00.htm
# 2190  /players/H/HileVa20.htm
# 3782                      NaN
# 3439                      NaN
# 4491                      NaN
# 2043  /players/C/ConrJ.20.htm
# 728   /players/S/SmitTo00.htm
# 4352                      NaN
# 1593  /players/S/StewKo00.htm
# 5046                      NaN
# 203
# 2033  /players/B/BranDa20.htm
# 4120                      NaN
# 634
# 4390                      NaN
# 1200  /players/W/WillKe00.htm
# 815   /players/S/SmitFr20.htm
# 2536  /players/M/McNaDo00.htm
# 5398                      NaN
# 477   /players/Y/YounDu00.htm
# 2213
# 3787                      NaN
# 4044                      NaN
# 3023                      NaN
# 2134
# 2293  /players/T/TaylLe20.htm
# 5062                      NaN
# 4999                      NaN
# 712   /players/M/MitcJo00.htm
# 3709                      NaN
# 37    /players/T/ThomAn00.htm
# 4272                      NaN
#
# [40 rows x 37 columns]

# %%
new_df.to_csv('df/newdf.csv')

# %%
mask = players.player_link == '/players/G/GeorJe00.htm'
players[mask]
# Out:
#   draft_round draft_pick team       player pos_x age year_max    g college_id  \
# 0           1          1  IND  Jeff George    QB  22     2001  131   Illinois
#
#                player_link  ... weight wonderlic forty_yd bench_reps vertical  \
# 0  /players/G/GeorJe00.htm  ...    NaN       NaN      NaN        NaN      NaN
#
#   broad_jump shuttle cone height_in DraftYr
# 0        NaN     NaN  NaN         0    1990
#
# [1 rows x 25 columns]

# %%
mask = collegedf.plink == '/players/G/GeorJe00.htm'
collegedf[mask]
# Out:
#       conf     cname                       cname_link  cseasons  cgames  \
# 0  Big Ten  Illinois  /cfb/schools/illinois/1989.html       3.0    34.0
#
#         player  year                                              clink  \
# 0  Jeff George  1990  http://www.sports-reference.com/cfb/players/je...
#
#                      plink
# 0  /players/G/GeorJe00.htm

# %%
collegedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3929 entries, 0 to 3928
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   conf        1299 non-null   object
#  1   cname       1299 non-null   object
#  2   cname_link  1299 non-null   object
#  3   cseasons    1299 non-null   float64
#  4   cgames      1299 non-null   float64
#  5   player      0 non-null      float64
#  6   year        3929 non-null   int64
#  7   clink       3929 non-null   object
#  8   plink       3929 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 276.4+ KB

# %%
collegedf.player.nunique()
# Out:
# 327

# %%
collegedf.player.value_counts()
# Out:
# James Williams        84
# Anthony Thompson      42
# Ron Lewis             42
# Pat Newman            21
# Clemente Gordon       21
#                       ..
# Ray Agnew             21
# Mohammed Elewonibi    21
# Donnie Salum          21
# Sean Smith            21
# Eddie Miles           21
# Name: player, Length: 327, dtype: int64

# %%
collegedf.plink.value_counts()
# Out:
#                            2121
# /players/W/WillJa23.htm      42
# /players/W/WillJa24.htm      42
# /players/R/RobiJe20.htm      21
# /players/R/RobiJu20.htm      21
#                            ...
# /players/M/MitcSc00.htm      21
# /players/D/DougDe20.htm      21
# /players/B/BrouSt00.htm      21
# /players/S/StayJo20.htm      21
# /players/P/PattMa21.htm      21
# Name: plink, Length: 230, dtype: int64

# %%
players.sample(20)
# Out:
#     draft_round draft_pick team               player pos_x age year_max    g  \
# 19            1         19  ATL           Tony Smith    RB  22     1994   33
# 62            2         63  GNB      Brandon Jackson    RB  21     2012   54
# 201           7        202  CIN        Marcus Parker    RB
# 52            2         53  MIA            Todd Wade     T  23     2007   99
# 212           8        211  CIN          Mike Dingle    RB  22     1991    8
# 34            2         35  STL    James Laurinaitis    LB  22     2016  117
# 128           4        129  NYG          Guy Whimper    DE  23     2013   78
# 36            2         37  ATL        Curtis Lofton    LB  22     2015  128
# 19            1         20  NOR            Irv Smith    TE  21     1999   95
# 66            3         67  HOU        Chris Sanders    WR  23     2001   97
# 66            3         67  TAM          Myron Lewis    DB  22     2012   28
# 221           7        222  BUF       Derek Schouman    TE  22     2010   25
# 132           4        133  TAM          Austin King     C  22     2006   34
# 2             1          3  HOU        Andre Johnson    WR  22     2016  193
# 12            1         13  NOR          Joe Johnson    DE  22     2003  117
# 200           8        198  NWE           Troy Brown    WR  22     2007  192
# 114           5        113  IND            Maury Toy    RB
# 41            2         40  KAN         Matt Blundin    QB  23     1997    3
# 53            2         54  TEN          Jason Jones    DE  22     2016  109
# 128           4        129  STL  Brandon Manumaleuna    TE  21     2010  158
#
#          college_id              player_link  ... weight wonderlic forty_yd  \
# 19    Southern Miss  /players/S/SmitTo00.htm  ...    189               9.99
# 62         Nebraska  /players/J/JackBr00.htm  ...    NaN       NaN      NaN
# 201   Virginia Tech                           ...    244               4.69
# 52      Mississippi  /players/W/WadeTo20.htm  ...    NaN       NaN      NaN
# 212  South Carolina  /players/D/DingMi00.htm  ...    240               4.85
# 34         Ohio St.  /players/L/LaurJa99.htm  ...    NaN       NaN      NaN
# 128   East Carolina  /players/W/WhimGu20.htm  ...    NaN       NaN      NaN
# 36         Oklahoma  /players/L/LoftCu99.htm  ...    NaN       NaN      NaN
# 19       Notre Dame  /players/S/SmitIr00.htm  ...    255               4.81
# 66         Ohio St.  /players/S/SandCh00.htm  ...    184               4.54
# 66       Vanderbilt  /players/L/LewiMy99.htm  ...    NaN       NaN      NaN
# 221       Boise St.  /players/S/SchoDe00.htm  ...    NaN       NaN      NaN
# 132    Northwestern  /players/K/KingAu20.htm  ...    NaN       NaN      NaN
# 2        Miami (FL)  /players/J/JohnAn02.htm  ...    NaN       NaN      NaN
# 12       Louisville  /players/J/JohnJo04.htm  ...    285               5.11
# 200        Marshall  /players/B/BrowTr00.htm  ...    NaN       NaN      NaN
# 114            UCLA                           ...    NaN       NaN      NaN
# 41         Virginia  /players/B/BlunMa00.htm  ...    228               4.99
# 53   East. Michigan  /players/J/JoneJa99.htm  ...    NaN       NaN      NaN
# 128         Arizona  /players/M/ManuBr00.htm  ...    NaN       NaN      NaN
#
#     bench_reps vertical broad_jump shuttle  cone height_in DraftYr
# 19                                    9.99  9.99         0    1992
# 62         NaN      NaN        NaN     NaN   NaN         0    2007
# 201         18     36.0        111    4.36  7.97         0    1998
# 52         NaN      NaN        NaN     NaN   NaN         0    2000
# 212                31.0        106    4.71  9.99         0    1991
# 34         NaN      NaN        NaN     NaN   NaN         0    2009
# 128        NaN      NaN        NaN     NaN   NaN         0    2006
# 36         NaN      NaN        NaN     NaN   NaN         0    2008
# 19          16     31.5        118    4.46  9.99         0    1993
# 66                 38.0        121    4.09  9.99         0    1995
# 66         NaN      NaN        NaN     NaN   NaN         0    2010
# 221        NaN      NaN        NaN     NaN   NaN         0    2007
# 132        NaN      NaN        NaN     NaN   NaN         0    2003
# 2          NaN      NaN        NaN     NaN   NaN         0    2003
# 12          23     33.5        122    4.34  9.99         0    1994
# 200        NaN      NaN        NaN     NaN   NaN         0    1993
# 114        NaN      NaN        NaN     NaN   NaN         0    1992
# 41                 25.5        103    4.53  9.99         0    1992
# 53         NaN      NaN        NaN     NaN   NaN         0    2008
# 128        NaN      NaN        NaN     NaN   NaN         0    2001
#
# [20 rows x 25 columns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 620977 entries, 0 to 620976
# Data columns (total 34 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   draft_round   620977 non-null  object
#  1   draft_pick    620977 non-null  object
#  2   team          620977 non-null  object
#  3   player_x      620977 non-null  object
#  4   pos_x         620977 non-null  object
#  5   age           620977 non-null  object
#  6   year_max      620977 non-null  object
#  7   g             620977 non-null  object
#  8   college_id    620977 non-null  object
#  9   player_link   620977 non-null  object
#  10  college_link  620977 non-null  object
#  11  year_x        248190 non-null  object
#  12  school_name   375956 non-null  object
#  13  pos_y         375956 non-null  object
#  14  height        375956 non-null  object
#  15  weight        375956 non-null  object
#  16  wonderlic     248190 non-null  object
#  17  forty_yd      375956 non-null  object
#  18  bench_reps    375956 non-null  object
#  19  vertical      375956 non-null  object
#  20  broad_jump    375956 non-null  object
#  21  shuttle       375956 non-null  object
#  22  cone          375956 non-null  object
#  23  height_in     620977 non-null  int64
#  24  DraftYr       620977 non-null  int64
#  25  conf          287987 non-null  object
#  26  cname         287987 non-null  object
#  27  cname_link    287987 non-null  object
#  28  cseasons      287987 non-null  float64
#  29  cgames        287987 non-null  float64
#  30  player_y      620977 non-null  object
#  31  year_y        620977 non-null  int64
#  32  clink         620977 non-null  object
#  33  plink         620977 non-null  object
# dtypes: float64(2), int64(3), object(29)
# memory usage: 165.8+ MB

# %%
new_df.player_link.nunique()
# Out:
# 4687

# %%
sum(players.duplicated())
# Out:
# 0

# %%
sum(collegedf.duplicated())
# Out:
# 24

# %%
collegedf[collegedf.duplicated()]
# Out:
#          conf                 cname  \
# 16        NaN                   NaN
# 159       NaN                   NaN
# 30        Ind         Florida State
# 207       NaN                   NaN
# 248    Pac-10                  UCLA
# 17        SWC             Texas A&M
# 20        Ind  Southern Mississippi
# 161       Ind            Notre Dame
# 188    Pac-10                  UCLA
# 44        NaN                   NaN
# 47   Big East            Miami (FL)
# 128    Pac-10                  UCLA
# 202       NaN                   NaN
# 17        SWC             Texas A&M
# 92        WAC          Fresno State
# 212       NaN                   NaN
# 227    Big 12                 Texas
# 213      CUSA               Houston
# 93     Big 12              Colorado
# 1         MWC                  Utah
# 16     Big 12                 Texas
# 73     Pac-10              Stanford
# 208    Pac-10            Washington
# 69        ACC         Florida State
#
#                                       cname_link  cseasons  cgames  \
# 16                                           NaN       NaN     NaN
# 159                                          NaN       NaN     NaN
# 30          /cfb/schools/florida-state/1990.html       4.0    39.0
# 207                                          NaN       NaN     NaN
# 248                  /cfb/schools/ucla/1990.html       2.0    22.0
# 17               /cfb/schools/texas-am/1991.html       4.0    46.0
# 20   /cfb/schools/southern-mississippi/1991.html       3.0    33.0
# 161            /cfb/schools/notre-dame/1991.html       3.0    33.0
# 188                  /cfb/schools/ucla/1991.html       3.0    34.0
# 44                                           NaN       NaN     NaN
# 47               /cfb/schools/miami-fl/1992.html       3.0    32.0
# 128                  /cfb/schools/ucla/1992.html       4.0    41.0
# 202                                          NaN       NaN     NaN
# 17               /cfb/schools/texas-am/1995.html       1.0    11.0
# 92           /cfb/schools/fresno-state/1995.html       2.0    23.0
# 212                                          NaN       NaN     NaN
# 227                 /cfb/schools/texas/1996.html       3.0    28.0
# 213               /cfb/schools/houston/1999.html       2.0    21.0
# 93               /cfb/schools/colorado/2002.html       2.0    24.0
# 1                    /cfb/schools/utah/2004.html       3.0    25.0
# 16                  /cfb/schools/texas/2004.html       3.0    38.0
# 73               /cfb/schools/stanford/2004.html       4.0    44.0
# 208            /cfb/schools/washington/2003.html       3.0    36.0
# 69          /cfb/schools/florida-state/2006.html       2.0    26.0
#
#               player  year                                              clink  \
# 16    James Williams  1990
# 159   James Williams  1990
# 30    Reggie Johnson  1991  http://www.sports-reference.com/cfb/players/re...
# 207   Reggie Johnson  1991
# 248     Scott Miller  1991  http://www.sports-reference.com/cfb/players/sc...
# 17       Kevin Smith  1992  http://www.sports-reference.com/cfb/players/ke...
# 20        Tony Smith  1992  http://www.sports-reference.com/cfb/players/to...
# 161       Tony Smith  1992  http://www.sports-reference.com/cfb/players/to...
# 188      Kevin Smith  1992  http://www.sports-reference.com/cfb/players/ke...
# 44        Chad Brown  1993
# 47    Kevin Williams  1993  http://www.sports-reference.com/cfb/players/ke...
# 128   Kevin Williams  1993  http://www.sports-reference.com/cfb/players/ke...
# 202       Chad Brown  1993
# 17      Reggie Brown  1996  http://www.sports-reference.com/cfb/players/re...
# 92      Reggie Brown  1996  http://www.sports-reference.com/cfb/players/re...
# 212       Mark Smith  1997
# 227   Pat Fitzgerald  1997  http://www.sports-reference.com/cfb/players/pa...
# 213       Mike Green  2000  http://www.sports-reference.com/cfb/players/mi...
# 93       Chris Brown  2003  http://www.sports-reference.com/cfb/players/ch...
# 1         Alex Smith  2005  http://www.sports-reference.com/cfb/players/al...
# 16   Derrick Johnson  2005  http://www.sports-reference.com/cfb/players/de...
# 73        Alex Smith  2005  http://www.sports-reference.com/cfb/players/al...
# 208  Derrick Johnson  2005  http://www.sports-reference.com/cfb/players/de...
# 69      Buster Davis  2007  http://www.sports-reference.com/cfb/players/bu...
#
#                        plink
# 16   /players/W/WillJa23.htm
# 159  /players/W/WillJa24.htm
# 30   /players/J/JohnRe00.htm
# 207
# 248  /players/M/MillSc00.htm
# 17   /players/S/SmitKe26.htm
# 20   /players/S/SmitTo00.htm
# 161
# 188  /players/S/SmitKe24.htm
# 44   /players/B/BrowCh04.htm
# 47   /players/W/WillKe00.htm
# 128  /players/W/WillKe23.htm
# 202  /players/B/BrowCh20.htm
# 17   /players/B/BrowRe22.htm
# 92   /players/B/BrowRe00.htm
# 212  /players/S/SmitMa20.htm
# 227
# 213  /players/G/GreeMi00.htm
# 93   /players/B/BrowCh03.htm
# 1    /players/S/SmitAl03.htm
# 16   /players/J/JohnDe25.htm
# 73   /players/S/SmitAl02.htm
# 208  /players/J/JohnDe24.htm
# 69   /players/D/DaviBu99.htm

# %%
players.player_link.value_counts()
# Out:
#                            785
# /players/G/GreeMi00.htm      2
# /players/B/BrowCh03.htm      2
# /players/W/WillJa23.htm      2
# /players/S/SmitAl02.htm      2
#                           ...
# /players/F/FonoTo20.htm      1
# /players/M/MahaSe20.htm      1
# /players/A/AdibXa99.htm      1
# /players/M/McCoJa99.htm      1
# /players/H/HawkAr20.htm      1
# Name: player_link, Length: 4687, dtype: int64

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5493 entries, 0 to 253
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   draft_round   5493 non-null   object
#  1   draft_pick    5493 non-null   object
#  2   team          5493 non-null   object
#  3   player        5493 non-null   object
#  4   pos_x         5493 non-null   object
#  5   age           5493 non-null   object
#  6   year_max      5493 non-null   object
#  7   g             5493 non-null   object
#  8   college_id    5493 non-null   object
#  9   player_link   5493 non-null   object
#  10  college_link  5493 non-null   object
#  11  year          1986 non-null   object
#  12  school_name   4298 non-null   object
#  13  pos_y         4298 non-null   object
#  14  height        4298 non-null   object
#  15  weight        4298 non-null   object
#  16  wonderlic     1986 non-null   object
#  17  forty_yd      4298 non-null   object
#  18  bench_reps    4298 non-null   object
#  19  vertical      4298 non-null   object
#  20  broad_jump    4298 non-null   object
#  21  shuttle       4298 non-null   object
#  22  cone          4298 non-null   object
#  23  height_in     5493 non-null   int64
#  24  DraftYr       5493 non-null   int64
# dtypes: int64(2), object(23)
# memory usage: 1.1+ MB

# %%
mask = players.player_link == '/players/W/WillJa23.htm'
players[mask]
# Out:
#    draft_round draft_pick team          player pos_x age year_max   g  \
# 15           1         16  BUF  James Williams    DB  23     1996  70
# 16           1         16  BUF  James Williams    DB  23     1996  70
#
#     college_id              player_link  ... weight wonderlic forty_yd  \
# 15  Fresno St.  /players/W/WillJa23.htm  ...    172               4.34
# 16  Fresno St.  /players/W/WillJa23.htm  ...    223               4.74
#
#    bench_reps vertical broad_jump shuttle  cone height_in DraftYr
# 15          9     38.0        129    4.03  9.99         0    1990
# 16         19     32.0        114    4.44  9.99         0    1990
#
# [2 rows x 25 columns]

# %%
mask = players.player == 'James Williams'
players[mask]
# Out:
#     draft_round draft_pick team          player pos_x age year_max    g  \
# 15            1         16  BUF  James Williams    DB  23     1996   70
# 16            1         16  BUF  James Williams    DB  23     1996   70
# 158           6        158  NOR  James Williams    LB  21     1999  137
# 159           6        158  NOR  James Williams    LB  21     1999  137
# 174           6        175  SEA  James Williams    WR  22     2003   30
#
#           college_id              player_link  ... weight wonderlic forty_yd  \
# 15        Fresno St.  /players/W/WillJa23.htm  ...    172               4.34
# 16        Fresno St.  /players/W/WillJa23.htm  ...    223               4.74
# 158  Mississippi St.  /players/W/WillJa24.htm  ...    172               4.34
# 159  Mississippi St.  /players/W/WillJa24.htm  ...    223               4.74
# 174         Marshall  /players/W/WillJa01.htm  ...    180       NaN     4.59
#
#     bench_reps vertical broad_jump shuttle  cone height_in DraftYr
# 15           9     38.0        129    4.03  9.99         0    1990
# 16          19     32.0        114    4.44  9.99         0    1990
# 158          9     38.0        129    4.03  9.99         0    1990
# 159         19     32.0        114    4.44  9.99         0    1990
# 174                36.0        123    4.16  7.22        71    2000
#
# [5 rows x 25 columns]

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29748 entries, 0 to 902
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   draft_round         29748 non-null  object
#  1   draft_pick          29748 non-null  object
#  2   team                29748 non-null  object
#  3   player              2691 non-null   object
#  4   pos_x               29748 non-null  object
#  5   age                 29748 non-null  object
#  6   year_max            29748 non-null  object
#  7   g                   29748 non-null  object
#  8   college_id          29748 non-null  object
#  9   player_link         29748 non-null  object
#  10  college_link        29748 non-null  object
#  11  year                2691 non-null   object
#  12  playernametolink_x  29748 non-null  object
#  13  school_name         27163 non-null  object
#  14  pos_y               27163 non-null  object
#  15  height              27163 non-null  object
#  16  weight              27163 non-null  object
#  17  wonderlic           1986 non-null   object
#  18  forty_yd            27163 non-null  object
#  19  bench_reps          27163 non-null  object
#  20  vertical            27163 non-null  object
#  21  broad_jump          27163 non-null  object
#  22  shuttle             27163 non-null  object
#  23  cone                27163 non-null  object
#  24  playernametolink_y  28663 non-null  object
#  25  height_in           29748 non-null  int64
#  26  DraftYr             29748 non-null  int64
#  27  player_x            27057 non-null  object
#  28  year_x              27057 non-null  object
#  29  player_y            26677 non-null  object
#  30  year_y              26677 non-null  object
# dtypes: int64(2), object(29)
# memory usage: 7.3+ MB

# %%
players[players.year == '2005'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   draft_round         0 non-null      object
#  1   draft_pick          0 non-null      object
#  2   team                0 non-null      object
#  3   player              0 non-null      object
#  4   pos_x               0 non-null      object
#  5   age                 0 non-null      object
#  6   year_max            0 non-null      object
#  7   g                   0 non-null      object
#  8   college_id          0 non-null      object
#  9   player_link         0 non-null      object
#  10  college_link        0 non-null      object
#  11  year                0 non-null      object
#  12  playernametolink_x  0 non-null      object
#  13  school_name         0 non-null      object
#  14  pos_y               0 non-null      object
#  15  height              0 non-null      object
#  16  weight              0 non-null      object
#  17  wonderlic           0 non-null      object
#  18  forty_yd            0 non-null      object
#  19  bench_reps          0 non-null      object
#  20  vertical            0 non-null      object
#  21  broad_jump          0 non-null      object
#  22  shuttle             0 non-null      object
#  23  cone                0 non-null      object
#  24  playernametolink_y  0 non-null      object
#  25  height_in           0 non-null      int64
#  26  DraftYr             0 non-null      int64
#  27  player_x            0 non-null      object
#  28  year_x              0 non-null      object
#  29  player_y            0 non-null      object
#  30  year_y              0 non-null      object
# dtypes: int64(2), object(29)
# memory usage: 0.0+ bytes

# %%
players.year.value_counts(dropna = False)
# Out:
# NaN     27057
# 1992      339
# 1991      336
# 1990      332
# 1996      255
# 1999      252
# 1995      248
# 1997      241
# 1998      240
# 1993      227
# 1994      221
# Name: year, dtype: int64

# %%
players.forty_yd.value_counts(dropna = False)
# Out:
# NaN     1195
# 9.99     390
# 4.62      80
# 4.50      77
# 4.59      76
#         ...
# 5.74       1
# 5.77       1
# 5.69       1
# 4.22       1
# 5.59       1
# Name: forty_yd, Length: 150, dtype: int64

# %%
players.weight.value_counts(dropna = False)
# Out:
# NaN    1195
# 197      57
# 194      49
# 236      48
# 199      47
#        ...
# 339       1
# 370       1
# 348       1
# 358       1
# 366       1
# Name: weight, Length: 213, dtype: int64

# %%
4298 + 1195
# Out:
# 5493

# %%
players[players.year == '2001'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 245 entries, 0 to 244
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   draft_round   245 non-null    object
#  1   draft_pick    245 non-null    object
#  2   team          245 non-null    object
#  3   player        245 non-null    object
#  4   pos_x         245 non-null    object
#  5   age           245 non-null    object
#  6   year_max      245 non-null    object
#  7   g             245 non-null    object
#  8   college_id    245 non-null    object
#  9   player_link   245 non-null    object
#  10  college_link  245 non-null    object
#  11  year          245 non-null    object
#  12  school_name   205 non-null    object
#  13  pos_y         205 non-null    object
#  14  height        205 non-null    object
#  15  weight        205 non-null    object
#  16  wonderlic     0 non-null      object
#  17  forty_yd      205 non-null    object
#  18  bench_reps    205 non-null    object
#  19  vertical      205 non-null    object
#  20  broad_jump    205 non-null    object
#  21  shuttle       205 non-null    object
#  22  cone          205 non-null    object
#  23  height_in     245 non-null    int64
#  24  DraftYr       245 non-null    int64
# dtypes: int64(2), object(23)
# memory usage: 49.8+ KB

# %%
players[(players.year == '2001') & (players.forty_yd.isna())]
# Out:
#     draft_round draft_pick team                 player pos_x age year_max  \
# 48            2         49  NYJ          LaMont Jordan    RB  22     2009
# 63            3         64  ARI          Adrian Wilson    DB  21     2012
# 77            3         78  NYG          Will Peterson    DB  22     2010
# 97            4         98  ARI         Bill Gramatica     K  23     2004
# 101           4        102  ATL           Matt Stewart    LB  22     2006
# 115           4        116  STL            Milton Wynn    WR  22     2002
# 125           4        126  BAL            Ed Hartwell    LB  23     2006
# 127           4        128  SEA           Floyd Womack     T  22     2010
# 140           5        141  KAN             Bill Baber    TE  22     2004
# 152           5        153  NOR              Onomo Ojo    WR
# 153           5        154  WAS      Darnerien McCants    WR  24     2005
# 154           5        155  PHI            A.J. Feeley    QB  24     2011
# 157           5        158  OAK           Ray Perryman    DB  22     2004
# 159           5        160  NYG           John Markham     K
# 160           5        161  BAL           Chris Barnes    RB
# 161           5        162  NYG        Jonathan Carter    WR  22     2004
# 167           6        168  CIN          Riall Johnson    LB  23     2003
# 174           6        175  CAR              Dee Brown    RB  23     2006
# 177           6        178  BUF            Tony Driver    DB  24     2002
# 181           6        182  PIT           Roger Knight    LB  22     2004
# 184           6        185  NOR            Mitch White     T
# 186           6        187  MIA         Otis Leverette    DE  23     2004
# 191           6        192  TEN          Dan Alexander    RB  23     2003
# 193           6        194  BAL              Joe Maese     C  22     2005
# 196           6        197  STL       Francis St. Paul    WR
# 200           7        201  SDG          Brandon Gorin     T  23     2009
# 203           7        204  CIN    T.J. Houshmandzadeh    WR  23     2011
# 205           7        206  NYJ             James Reed    DT  24     2007
# 206           7        207  DAL  Colston Weatherington    DE  23     2002
# 222           7        223  TAM           Than Merrill    DB  23     2001
# 223           7        224  SFO           Eric Johnson    TE  21     2007
# 224           7        225  MIN         Brian Crawford     T
# 225           7        226  ATL         Ronald Flemons    DE  21     2004
# 234           7        235  JAX   Richmond Flowers III    WR
# 236           7        237  SEA           Kris Kocurek    DT  22     2001
# 237           7        238  BUF       Tyrone Robertson    DT  22     2001
# 239           7        240  DAL               John Nix    DT  24     2004
# 240           7        241  JAX         Randy Chevrier    DT  25     2001
# 241           7        242  DAL        Char-ron Dorsey     T  23     2002
# 242           7        243  KAN          Terdell Sands    DT  21     2009
#
#        g            college_id                player_link  ... weight  \
# 48   114              Maryland    /players/J/JordLa00.htm  ...    NaN
# 63   181    North Carolina St.    /players/W/WilsAd99.htm  ...    NaN
# 77    97        West. Illinois    /players/P/PeteWi20.htm  ...    NaN
# 97    34         South Florida  /players/G/gramabil01.htm  ...    NaN
# 101   93            Vanderbilt    /players/S/StewMa21.htm  ...    NaN
# 115    4        Washington St.    /players/W/WynnMi00.htm  ...    NaN
# 125   77        West. Illinois    /players/H/HartEd20.htm  ...    NaN
# 127  120       Mississippi St.    /players/W/WomaFl20.htm  ...    NaN
# 140   30              Virginia    /players/B/BabeBi00.htm  ...    NaN
# 152           California-Davis                             ...    NaN
# 153   41          Delaware St.    /players/M/McCaDa00.htm  ...    NaN
# 154   28                Oregon    /players/F/FeelA.00.htm  ...    NaN
# 157   10      Northern Arizona    /players/P/PerrRa21.htm  ...    NaN
# 159                 Vanderbilt                             ...    NaN
# 160             New Mexico St.                             ...    NaN
# 161   25                  Troy    /players/C/CartJo01.htm  ...    NaN
# 167   32              Stanford    /players/J/JohnRi20.htm  ...    NaN
# 174   43              Syracuse    /players/B/BrowDe02.htm  ...    NaN
# 177   11            Notre Dame    /players/D/DrivTo20.htm  ...    NaN
# 181   48             Wisconsin    /players/K/KnigRo20.htm  ...    NaN
# 184                 Oregon St.                             ...    NaN
# 186   17        Ala-Birmingham    /players/L/LeveOt20.htm  ...    NaN
# 191   11              Nebraska    /players/A/AlexDa21.htm  ...    NaN
# 193   65            New Mexico    /players/M/MaesJo20.htm  ...    NaN
# 196           Northern Arizona                             ...    NaN
# 200   48                Purdue    /players/G/GoriBr20.htm  ...    NaN
# 203  146            Oregon St.    /players/H/HousTJ00.htm  ...    NaN
# 205   99              Iowa St.    /players/R/ReedJa21.htm  ...    NaN
# 206    3  Central Missouri St.    /players/W/WeatCo20.htm  ...    NaN
# 222   15                  Yale    /players/M/MerrTh20.htm  ...    NaN
# 223   71                  Yale    /players/J/JohnEr00.htm  ...    NaN
# 224             Western Oregon                             ...    NaN
# 225    6             Texas A&M    /players/F/FlemRo20.htm  ...    NaN
# 234                Chattanooga                             ...    NaN
# 236    1            Texas Tech    /players/K/KocuKr20.htm  ...    NaN
# 237   12               Georgia    /players/R/RobeTy20.htm  ...    NaN
# 239   31         Southern Miss    /players/N/NixxJo20.htm  ...    NaN
# 240   13                McGill    /players/C/ChevRa20.htm  ...    NaN
# 241   12           Florida St.    /players/D/DorsCh20.htm  ...    NaN
# 242   77           Chattanooga    /players/S/SandTe20.htm  ...    NaN
#
#     wonderlic forty_yd bench_reps vertical broad_jump shuttle cone height_in  \
# 48        NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 63        NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 77        NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 97        NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 101       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 115       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 125       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 127       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 140       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 152       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 153       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 154       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 157       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 159       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 160       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 161       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 167       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 174       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 177       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 181       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 184       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 186       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 191       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 193       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 196       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 200       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 203       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 205       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 206       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 222       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 223       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 224       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 225       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 234       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 236       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 237       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 239       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 240       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 241       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
# 242       NaN      NaN        NaN      NaN        NaN     NaN  NaN         0
#
#     DraftYr
# 48     2001
# 63     2001
# 77     2001
# 97     2001
# 101    2001
# 115    2001
# 125    2001
# 127    2001
# 140    2001
# 152    2001
# 153    2001
# 154    2001
# 157    2001
# 159    2001
# 160    2001
# 161    2001
# 167    2001
# 174    2001
# 177    2001
# 181    2001
# 184    2001
# 186    2001
# 191    2001
# 193    2001
# 196    2001
# 200    2001
# 203    2001
# 205    2001
# 206    2001
# 222    2001
# 223    2001
# 224    2001
# 225    2001
# 234    2001
# 236    2001
# 237    2001
# 239    2001
# 240    2001
# 241    2001
# 242    2001
#
# [40 rows x 25 columns]

# %%
players[(players.year == '2001')].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   draft_round         0 non-null      object
#  1   draft_pick          0 non-null      object
#  2   team                0 non-null      object
#  3   player              0 non-null      object
#  4   pos_x               0 non-null      object
#  5   age                 0 non-null      object
#  6   year_max            0 non-null      object
#  7   g                   0 non-null      object
#  8   college_id          0 non-null      object
#  9   player_link         0 non-null      object
#  10  college_link        0 non-null      object
#  11  year                0 non-null      object
#  12  playernametolink_x  0 non-null      object
#  13  school_name         0 non-null      object
#  14  pos_y               0 non-null      object
#  15  height              0 non-null      object
#  16  weight              0 non-null      object
#  17  wonderlic           0 non-null      object
#  18  forty_yd            0 non-null      object
#  19  bench_reps          0 non-null      object
#  20  vertical            0 non-null      object
#  21  broad_jump          0 non-null      object
#  22  shuttle             0 non-null      object
#  23  cone                0 non-null      object
#  24  playernametolink_y  0 non-null      object
#  25  height_in           0 non-null      int64
#  26  DraftYr             0 non-null      int64
#  27  player_x            0 non-null      object
#  28  year_x              0 non-null      object
#  29  player_y            0 non-null      object
#  30  year_y              0 non-null      object
# dtypes: int64(2), object(29)
# memory usage: 0.0+ bytes

# %%
players
